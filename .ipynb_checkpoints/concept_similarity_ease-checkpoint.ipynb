# %% [markdown]
# ## EASE2022 Submission
#
# We will be using this notebook to extract corpus keywords and analyse the concepts emerging from three sources: source code, documentation and tests

# %%
import code_extract as ce
import test_extract as te
import doc_extract as de

import pandas as pd
import numpy as np

# %% [markdown]
# ## Top 5 Java Apache Maven Build Projects:
# - P1 - Apache Dubbo
# - P2 - Apache Skywalking
# - P3 - Apache Flink
# - P4 - Apache RocketMQ
# - P5 - Apache ShardingSphere

# %%
p1_name = ['apache','dubbo']

p1_modules = ['dubbo-cluster',
              'dubbo-common',
              'dubbo-compatible',
              'dubbo-config',
              'dubbo-configcenter',
              'dubbo-container',
              'dubbo-filter',
              'dubbo-metadata',
              'dubbo-monitor',
              'dubbo-plugin',
              'dubbo-registry',
              'dubbo-remoting',
              'dubbo-rpc',
              'dubbo-serialization']

# %%
p2_name = ['apache','skywalking']

p2_modules = ['apm-commons',
              'apm-protocol',
              'apm-webapp',
              'oap-server']

# %%
p3_name = ['apache','flink']

p3_modules = ['flink-clients',
              'flink-connectors',
              'flink-container',
              'flink-contrib',
              'flink-core',
              'flink-docs',
              'flink-dstl',
              'flink-examples',
              'flink-external-resources',
              'flink-filesystems',
              'flink-formats',
              'flink-java',
              'flink-kubernetes',
              'flink-libraries',
              'flink-metrics',
              'flink-optimizer',
              'flink-python',
              'flink-queryable-state',
              'flink-rpc',
              'flink-runtime',
              'flink-runtime-web',
              'flink-scala',
              'flink-state-backends',
              'flink-streaming-java',
              'flink-streaming-scala',
              'flink-table',
              'flink-yarn']

# %%
p4_name = ['apache','rocketmq']

p4_modules = ['acl',
              'broker',
              'client',
              'common',
              'filter',
              'logappender',
              'logging',
              'namesrv',
              'openmessaging',
              'remoting',
              'srvutil',
              'store',
              'tools']

# %%
p5_name = ['apache','shardingsphere']

p5_modules = ['shardingsphere-agent',
              'shardingsphere-db-protocol',
              'shardingsphere-features',
              'shardingsphere-infra',
              'shardingsphere-jdbc',
              'shardingsphere-kernel',
              'shardingsphere-mode',
              'shardingsphere-proxy',
              'shardingsphere-scaling',
              'shardingsphere-spi',
              'shardingsphere-sql-parser']

# %%
import spacy

nlp = spacy.load('en_core_web_md')
nlp.max_length = 4000000

# %% [markdown]
# ### Extract

# %%
p1_code = []

for module in p1_modules:
    p1_code.append(ce.extract_from_code('repo/dubbo/{}/'.format(module), p1_name, nlp))

# %%
p2_code = []

for module in p2_modules:
    p2_code.append(ce.extract_from_code('repo/skywalking/{}/'.format(module), p2_name, nlp))

# %%
p3_code = []

for module in p3_modules:
    p3_code.append(ce.extract_from_code('repo/flink/{}/'.format(module), p3_name, nlp))

# %%
p4_code = []

for module in p4_modules:
    p4_code.append(ce.extract_from_code('repo/rocketmq/{}/'.format(module), p4_name, nlp))

# %%
p5_code = []

for module in p5_modules:
    p5_code.append(ce.extract_from_code('repo/shardingsphere/{}/'.format(module), p5_name, nlp))

# %%
p1_test = []

for module in p1_modules:
    p1_test.append(te.extract_from_test('repo/dubbo/{}/'.format(module), p1_name, nlp))

# %%
p2_test = []

for module in p2_modules:
    p2_test.append(te.extract_from_test('repo/skywalking/{}/'.format(module), p2_name, nlp))

# %%
p3_test = []

for module in p3_modules:
    p3_test.append(te.extract_from_test('repo/flink/{}/'.format(module), p3_name, nlp))

# %%
p4_test = []

for module in p4_modules:
    p4_test.append(te.extract_from_test('repo/rocketmq/{}/'.format(module), p4_name, nlp))

# %%
p5_test = []

for module in p5_modules:
    p5_test.append(te.extract_from_test('repo/shardingsphere/{}/'.format(module), p5_name, nlp))

# %%
p1_doc = de.extract_from_doc('repo/dubbo/', p1_name, nlp)

# %%
p1_doc
# Out:
# 'project highperformance javabased opensource rpc framework please visit official site quick start documentation well wiki news faq release note collect user info help improve kindly support supplementing information issue want who s use thank architecture feature transparent interface base rpc intelligent load balance automatic service registration discovery high extensibility runtime traffic route visualize service governance get start follow code snippet come sample may clone sample project step subdirectory proceed there s readme file directory recommend reference sample directory follow belowmentioned instruction maven dependency define service interface see apigreetingsservicejava github implement service interface provider see providergreetingsserviceimpljava github start service provider see providerapplicationjava github build run provider call remote service consumer see consumerapplicationjava github build run consumer consumer print screen next step first application tuto
# ...

# %%
p2_doc = de.extract_from_doc('repo/skywalking/', p2_name, nlp)

# %%
p2_doc
# Out:
# 'apmapplication performance monitor system especially design microservices cloud native containerbased architectures abstract open source apm system include monitor trace diagnose capability distribute system cloud native architecture core feature follow service service instance endpoint metric analysis root cause analysis profile code runtime service topology map analysis service service instance endpoint dependency analysis slow service endpoint detect performance optimization distribute trace context propagation database access metric detect slow database access statementsincluding sql statement message queue performance consume latency monitor alarm browser performance monitor infrastructurevm network disk etc monitor collaboration across metric trace log support collect telemetry metric trace logs data multiple source multiple format include java net core nodejs php python autoinstrument agent sdks lua agent especially nginx openresty apisix browser agent service mesh observabil
# ...

# %%
p3_doc = de.extract_from_doc('repo/flink/', p3_name, nlp)

# %%
p3_doc
# Out:
# 'open source stream processing framework powerful stream batchprocessing capability learn httpsflinkapacheorg feature streamingfirst runtime support batch processing datum streaming program elegant fluent apis java scala runtime support high throughput low event latency time support event time outoforder process datastream api base dataflow model flexible windowing time count session custom trigger across different time semantic event time processing time faulttolerance exactlyonce processing guarantee natural backpressure streaming program library graph process batch machine learning batch complex event processing streaming builtin support iterative program bsp dataset batch api custom memory management efficient robust switch inmemory outofcore datum processing algorithm compatibility layer hadoop mapreduce integration yarn hdfs hbase component hadoop ecosystem stream example batch example building source prerequisite build unixlike environment use linux mac cygwin wsl git maven re
# ...

# %%
p4_doc = de.extract_from_doc('repo/rocketmq/', p4_name, nlp)

# %%
p4_doc
# Out:
# 'distribute messaging streaming platform low latency high performance reliability trillionlevel capacity flexible scalability offer variety feature messaging pattern include publishsubscribe requestreply stream financial grade transactional message builtin fault tolerance high availability configuration option base dledger variety cross language client java python nodejs pluggable transport protocols tcp ssl aio builtin message trace capability also support opentrace versatile bigdata stream ecosytem integration message retroactivity time offset reliable fifo strict order messaging queue efficient pull push consumption model millionlevel message accumulation capacity single queue multiple messaging protocol like jms openmessaging flexible distribute scaleout deployment architecture lightningfast batch message exchange system various message filter mechanic sql tag docker image isolate testing cloud isolate cluster featurerich administrative dashboard configuration metric monitor auth
# ...

# %%
p5_doc = de.extract_from_doc('repo/shardingsphere/', p5_name, nlp)

# %%
p5_doc
# Out:
# 'building criterion ecosystem multimodel databases official website httpsshardingsphereapacheorg stargazers time contributor time overview position database plus aim build new criterion ecosystem multimodel database focus reuse exist database respective upper layer rather create new database concept core project link enhance pluggable flexible adaptation database protocol sql dialect database storage quickly link application multimode heterogeneous database quickly capture database access entry provide additional feature transparently redirect sharding readwritesplitte shadow transform datum encrypt mask authentication security audit authority governance circuit breaker access limitation analyze qos observability leverage micro kernel layer pluggable mode feature database ecosystem embed flexibily developer customize like building lego block become toplevel project april documentation full documentation amp detail visit docs contribution guide get start setup environment contributor 
# ...

# %%
with open("output/p1_doc.txt", "w") as text_file:
    text_file.write(p1_doc)

# %%
with open("output/p2_doc.txt", "w") as text_file:
    text_file.write(p2_doc)

# %%
with open("output/p3_doc.txt", "w") as text_file:
    text_file.write(p3_doc)

# %%
with open("output/p4_doc.txt", "w") as text_file:
    text_file.write(p4_doc)

# %%
with open("output/p5_doc.txt", "w") as text_file:
    text_file.write(p5_doc)

# %%
p1_code_clean = [len(x.replace(',', ' ').split()) for x in p1_code]
p1_test_clean = [len(x.replace(',', ' ').split()) for x in p1_test]

# %%
p2_code_clean = [len(x.replace(',', ' ').split()) for x in p2_code]
p2_test_clean = [len(x.replace(',', ' ').split()) for x in p2_test]

# %%
p3_code_clean = [len(x.replace(',', ' ').split()) if type(x) is not float else 0 for x in p3_code]
p3_test_clean = [len(x.replace(',', ' ').split()) if type(x) is not float else 0 for x in p3_test]

# %%
p4_code_clean = [len(x.replace(',', ' ').split()) if type(x) is not float else 0 for x in p4_code]
p4_test_clean = [len(x.replace(',', ' ').split()) if type(x) is not float else 0 for x in p4_test]

# %%
p5_code_clean = [len(x.replace(',', ' ').split()) if type(x) is not float else 0 for x in p5_code]
p5_test_clean = [len(x.replace(',', ' ').split()) if type(x) is not float else 0 for x in p5_test]

# %%
p1_data_df = pd.DataFrame(np.transpose([p1_modules, p1_code, p1_code_clean, p1_test, p1_test_clean]), columns=['P1 Module', 'Code Extraction', 'Code Length', 'Test Extraction', 'Test Length'])
p1_data_df['Doc Extraction'] = p1_doc
p1_data_df
# Out:
#               P1 Module                                    Code Extraction  \
# 0         dubbo-cluster  cacheable router factory router factory concur...
# 1          dubbo-common  activate,reference,service,service metadata co...
# 2      dubbo-compatible  cache cache,cache factory cache factory,cache ...
# 3          dubbo-config  config initializer,config processor,shutdown h...
# 4    dubbo-configcenter  apollo dynamic configuration dynamic configura...
# 5       dubbo-container  container,container key shutdown hook key logg...
# 6          dubbo-filter  cache,cache factory,cache filter filter cache ...
# 7        dubbo-metadata  metadata param filter metadata param filter se...
# 8         dubbo-monitor  constant,metric service,monitor node monitor s...
# 9          dubbo-plugin  access key authenticator authenticator sign in...
# 10       dubbo-registry  address listener,constant,listener registry wr...
# ...

# %%
p2_data_df = pd.DataFrame(np.transpose([p2_modules, p2_code, p2_code_clean, p2_test, p2_test_clean]), columns=['P2 Module', 'Code Extraction', 'Code Length', 'Test Extraction', 'Test Length'])
p2_data_df['Doc Extraction'] = p2_doc
p2_data_df
# Out:
#       P2 Module                                    Code Extraction  \
# 0   apm-commons  carrier channel channel driver driver carrier ...
# 1  apm-protocol  profile constant task duration min minute task...
# 2    apm-webapp  application,error web handler error web handle...
# 3    oap-server  analyzer module module define analyzer module ...
#
#   Code Length                                    Test Extraction Test Length  \
# 0         535  carrier create carrier illegal access produce ...         250
# 1         179  grpc server interrupt next command value error...           9
# 2          14                   application context context load           4
# 3       32568  trace sampling policy watcher analyzer module ...        6142
#
#                                       Doc Extraction
# 0  apmapplication performance monitor system espe...
# 1  apmapplication performance monitor system espe...
# 2  apmapplication performance monitor system espe...
# ...

# %%
p3_data_df = pd.DataFrame(np.transpose([p3_modules, p3_code, p3_code_clean, p3_test, p3_test_clean]), columns=['P3 Module', 'Code Extraction', 'Code Length', 'Test Extraction', 'Test Length'])
p3_data_df['Doc Extraction'] = p3_doc
p3_data_df
# Out:
#                    P3 Module  \
# 0              flink-clients
# 1           flink-connectors
# 2            flink-container
# 3              flink-contrib
# 4                 flink-core
# 5                 flink-docs
# 6                 flink-dstl
# 7             flink-examples
# 8   flink-external-resources
# 9          flink-filesystems
# 10             flink-formats
# 11                flink-java
# 12          flink-kubernetes
# 13           flink-libraries
# 14             flink-metrics
# 15           flink-optimizer
# 16              flink-python
# 17     flink-queryable-state
# 18                 flink-rpc
# 19             flink-runtime
# 20         flink-runtime-web
# 21               flink-scala
# 22      flink-state-backends
# 23      flink-streaming-java
# 24     flink-streaming-scala
# 25               flink-table
# 26                flink-yarn
#
#                                       Code Extraction Code Length  \
# ...

# %%
p4_data_df = pd.DataFrame(np.transpose([p4_modules, p4_code, p4_code_clean, p4_test, p4_test_clean]), columns=['P4 Module', 'Code Extraction', 'Code Length', 'Test Extraction', 'Test Length'])
p4_data_df['Doc Extraction'] = p4_doc
p4_data_df
# Out:
#         P4 Module                                    Code Extraction  \
# 0             acl  access resource,access validator,acl client rp...
# 1          broker  broker controller internal logger log internal...
# 2          client  access channel,client config send message vip ...
# 3          common  acl config list white addrs list plain access ...
# 4          filter  filter factory filter factory instance filter ...
# 5     logappender  producer instance appender type appender type ...
# 6         logging  inner logger factory internal logger factory i...
# 7         namesrv  namesrv controller internal logger log interna...
# 8   openmessaging  messaging access point impl messaging access p...
# 9        remoting  channel event listener,command custom header,i...
# 10        srvutil  watch service service thread internal logger l...
# 11          store  allocate map service service thread internal l...
# 12          tools  admin ext client config admin ext admin ext im...
#
# ...

# %%
p5_data_df = pd.DataFrame(np.transpose([p5_modules, p5_code, p5_code_clean, p5_test, p5_test_clean]), columns=['P5 Module', 'Code Extraction', 'Code Length', 'Test Extraction', 'Test Length'])
p5_data_df['Doc Extraction'] = p5_doc
p5_data_df
# Out:
#                      P5 Module  \
# 0         shardingsphere-agent
# 1   shardingsphere-db-protocol
# 2      shardingsphere-features
# 3         shardingsphere-infra
# 4          shardingsphere-jdbc
# 5        shardingsphere-kernel
# 6          shardingsphere-mode
# 7         shardingsphere-proxy
# 8       shardingsphere-scaling
# 9           shardingsphere-spi
# 10   shardingsphere-sql-parser
#
#                                       Code Extraction Code Length  \
# 0   advice target object,method around advice,cons...        3145
# 1   common constant attribute key charset charset ...        5612
# 2   database discovery rule configuration schema r...       26897
# 3   logic sql sql statement context sql statement ...       14511
# 4   sharding sphere source factory source create s...        7817
# 5   authority rule configuration rule configuratio...        9529
# 6   context manager auto closeable meta contexts m...        3076
# ...

# %%
p1_data_df.to_csv("output/p1_data_df.csv", index=False)
p2_data_df.to_csv("output/p2_data_df.csv", index=False)
p3_data_df.to_csv("output/p3_data_df.csv", index=False)
p4_data_df.to_csv("output/p4_data_df.csv", index=False)
p5_data_df.to_csv("output/p5_data_df.csv", index=False)

# %% [markdown]
# ### Similarity Measurements

# %% [markdown]
# All feature extraction will then be measured through cos similarity.
#
# Types of feature extraction:
# - TFIDF
# - SO W2V
# - SpaCy md
# - FastText

# %% [markdown]
# ### METHODOLOGY
#
# 1 - Between Source Code and Tests (CODE/TEST):\
# We will look at per module basis. Every module will be scored a similarity score between code and the tests.
#
# 2 - Between Source Code and Doc (CODE/DOC) and Tests and Doc (TEST/DOC)
#
# 3 - Correlation for CODE/DOC and TEST/DOC
#
# 4 - Topic modelling to identify concept drift in outliers

# %% [markdown]
# ### 1 - CODE/TEST Similarity:

# %% [markdown]
# #### Cosine Similarity with TFIDF Vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

p1_tfidf = []

tfidf_vectorizer = TfidfVectorizer()

i = 0

while i < len(p1_modules):
    p1_tfidf.append(tfidf_vectorizer.fit_transform([p1_code[i], p1_test[i]]))
    i+=1

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

p2_tfidf = []

tfidf_vectorizer = TfidfVectorizer()

i = 0

while i < len(p2_modules):
    p2_tfidf.append(tfidf_vectorizer.fit_transform([p2_code[i], p2_test[i]]))
    i+=1

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

p3_tfidf = []

tfidf_vectorizer = TfidfVectorizer()

i = 0

while i < len(p3_modules):
    p3_tfidf.append(tfidf_vectorizer.fit_transform([p3_code[i], p3_test[i]]))
    i+=1

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

p4_tfidf = []

tfidf_vectorizer = TfidfVectorizer()

i = 0

while i < len(p4_modules):
    p4_tfidf.append(tfidf_vectorizer.fit_transform([p4_code[i], p4_test[i]]))
    i+=1

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

p5_tfidf = []

tfidf_vectorizer = TfidfVectorizer()

i = 0

while i < len(p5_modules):
    p5_tfidf.append(tfidf_vectorizer.fit_transform([p5_code[i], p5_test[i]]))
    i+=1

# %%
p1_tfidf
# Out:
# [<2x296 sparse matrix of type '<class 'numpy.float64'>'
#  	with 402 stored elements in Compressed Sparse Row format>,
#  <2x934 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1314 stored elements in Compressed Sparse Row format>,
#  <2x281 sparse matrix of type '<class 'numpy.float64'>'
#  	with 361 stored elements in Compressed Sparse Row format>,
#  <2x513 sparse matrix of type '<class 'numpy.float64'>'
#  	with 734 stored elements in Compressed Sparse Row format>,
#  <2x109 sparse matrix of type '<class 'numpy.float64'>'
#  	with 140 stored elements in Compressed Sparse Row format>,
#  <2x24 sparse matrix of type '<class 'numpy.float64'>'
#  	with 28 stored elements in Compressed Sparse Row format>,
#  <2x86 sparse matrix of type '<class 'numpy.float64'>'
#  	with 106 stored elements in Compressed Sparse Row format>,
#  <2x393 sparse matrix of type '<class 'numpy.float64'>'
#  	with 536 stored elements in Compressed Sparse Row format>,
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

def get_cos_sim(code, test):
    return cosine_similarity(code, test)

# %%
p1_tfidf_res = []
i = 0

while i < len(p1_modules):
    res = ( p1_modules[i], get_cos_sim(p1_tfidf[i], p1_tfidf[i])[0][1] )
    p1_tfidf_res.append(res)
    i+=1
    
p1_res1_df = pd.DataFrame(p1_tfidf_res, columns=['P1 Module','TFIDF'])
p1_res1_df
# Out:
#               P1 Module     TFIDF
# 0         dubbo-cluster  0.694818
# 1          dubbo-common  0.608003
# 2      dubbo-compatible  0.485747
# 3          dubbo-config  0.517267
# 4    dubbo-configcenter  0.686780
# 5       dubbo-container  0.679380
# 6          dubbo-filter  0.522603
# 7        dubbo-metadata  0.682664
# 8         dubbo-monitor  0.764186
# 9          dubbo-plugin  0.493402
# 10       dubbo-registry  0.901452
# 11       dubbo-remoting  0.840885
# 12            dubbo-rpc  0.280882
# 13  dubbo-serialization  0.506218

# %%
p2_tfidf_res = []
i = 0

while i < len(p2_modules):
    res = ( p2_modules[i], get_cos_sim(p2_tfidf[i], p2_tfidf[i])[0][1] )
    p2_tfidf_res.append(res)
    i+=1
    
p2_res1_df = pd.DataFrame(p2_tfidf_res, columns=['P2 Module','TFIDF'])
p2_res1_df
# Out:
#       P2 Module     TFIDF
# 0   apm-commons  0.326697
# 1  apm-protocol  0.187707
# 2    apm-webapp  0.042718
# 3    oap-server  0.811193

# %%
p3_tfidf_res = []
i = 0

while i < len(p3_modules):
    res = ( p3_modules[i], get_cos_sim(p3_tfidf[i], p3_tfidf[i])[0][1] )
    p3_tfidf_res.append(res)
    i+=1
    
p3_res1_df = pd.DataFrame(p3_tfidf_res, columns=['P3 Module','TFIDF'])
p3_res1_df
# Out:
#                    P3 Module     TFIDF
# 0              flink-clients  0.820911
# 1           flink-connectors  0.824692
# 2            flink-container  0.478378
# 3              flink-contrib  0.216004
# 4                 flink-core  0.829508
# 5                 flink-docs  0.610350
# 6                 flink-dstl  0.590040
# 7             flink-examples  0.181599
# 8   flink-external-resources  0.495939
# 9          flink-filesystems  0.522374
# 10             flink-formats  0.759770
# 11                flink-java  0.653812
# 12          flink-kubernetes  0.898674
# 13           flink-libraries  0.697150
# 14             flink-metrics  0.841537
# 15           flink-optimizer  0.399481
# 16              flink-python  0.758405
# 17     flink-queryable-state  0.674129
# 18                 flink-rpc  0.853675
# 19             flink-runtime  0.918360
# 20         flink-runtime-web  0.748484
# 21               flink-scala  0.598481
# 22      flink-state-backends  0.883065
# ...

# %%
p4_tfidf_res = []
i = 0

while i < len(p4_modules):
    res = ( p4_modules[i], get_cos_sim(p4_tfidf[i], p4_tfidf[i])[0][1] )
    p4_tfidf_res.append(res)
    i+=1
    
p4_res1_df = pd.DataFrame(p4_tfidf_res, columns=['P4 Module','TFIDF'])
p4_res1_df
# Out:
#         P4 Module     TFIDF
# 0             acl  0.673354
# 1          broker  0.822696
# 2          client  0.755249
# 3          common  0.560394
# 4          filter  0.539869
# 5     logappender  0.038362
# 6         logging  0.521046
# 7         namesrv  0.674293
# 8   openmessaging  0.529480
# 9        remoting  0.519058
# 10        srvutil  0.136740
# 11          store  0.761854
# 12          tools  0.342913

# %%
p5_tfidf_res = []
i = 0

while i < len(p5_modules):
    res = ( p5_modules[i], get_cos_sim(p5_tfidf[i], p5_tfidf[i])[0][1] )
    p5_tfidf_res.append(res)
    i+=1
    
p5_res1_df = pd.DataFrame(p5_tfidf_res, columns=['P5 Module','TFIDF'])
p5_res1_df
# Out:
#                      P5 Module     TFIDF
# 0         shardingsphere-agent  0.772023
# 1   shardingsphere-db-protocol  0.941803
# 2      shardingsphere-features  0.933575
# 3         shardingsphere-infra  0.884716
# 4          shardingsphere-jdbc  0.888897
# 5        shardingsphere-kernel  0.747177
# 6          shardingsphere-mode  0.812701
# 7         shardingsphere-proxy  0.897779
# 8       shardingsphere-scaling  0.769502
# 9           shardingsphere-spi  0.601100
# 10   shardingsphere-sql-parser  0.563670

# %% [markdown]
# #### Cosine Similarity with Averaged Word2Vec

# %%
from gensim.models.keyedvectors import KeyedVectors
from nltk import word_tokenize

so_w2v_model = KeyedVectors.load_word2vec_format('C:/Users/biadge/OneDrive - BP/PhD/extraction/SO_vectors_200.bin', binary=True)
# Out:
# INFO:gensim.models.utils_any2vec:loading projection weights from C:/Users/biadge/OneDrive - BP/PhD/extraction/SO_vectors_200.bin
# DEBUG:smart_open.smart_open_lib:{'uri': 'C:/Users/biadge/OneDrive - BP/PhD/extraction/SO_vectors_200.bin', 'mode': 'rb', 'buffering': -1, 'encoding': None, 'errors': None, 'newline': None, 'closefd': True, 'opener': None, 'ignore_ext': False, 'transport_params': None}
# INFO:gensim.models.utils_any2vec:loaded (1787145, 200) matrix from C:/Users/biadge/OneDrive - BP/PhD/extraction/SO_vectors_200.bin

# %%
import numpy as np
from scipy import spatial

index2word_set = set(so_w2v_model.index2word)

def avg_feature_vector(sentence, model=so_w2v_model, num_features=200, index2word_set=index2word_set):
    words = sentence.split()
    feature_vec = np.zeros((num_features, ), dtype='float32')
    n_words = 0
    for word in words:
        if word in index2word_set:
            n_words += 1
            feature_vec = np.add(feature_vec, model[word])
    if (n_words > 0):
        feature_vec = np.divide(feature_vec, n_words)
    return feature_vec

# %%
p1_sow2v_res = []
i = 0

while i < len(p1_modules):
    code_vector = avg_feature_vector(p1_code[i])
    test_vector = avg_feature_vector(p1_test[i])
    res = ( p1_modules[i], 1 - spatial.distance.cosine(code_vector, test_vector) )
    p1_sow2v_res.append(res)
    i+=1
    
p1_res2_df = pd.DataFrame(p1_sow2v_res, columns=['P1 Module','W2V'])
p1_res2_df
# Out:
#               P1 Module       W2V
# 0         dubbo-cluster  0.931694
# 1          dubbo-common  0.952701
# 2      dubbo-compatible  0.906468
# 3          dubbo-config  0.945942
# 4    dubbo-configcenter  0.952474
# 5       dubbo-container  0.851279
# 6          dubbo-filter  0.848411
# 7        dubbo-metadata  0.944727
# 8         dubbo-monitor  0.932354
# 9          dubbo-plugin  0.935700
# 10       dubbo-registry  0.987535
# 11       dubbo-remoting  0.976006
# 12            dubbo-rpc  0.831779
# 13  dubbo-serialization  0.896277

# %%
p2_sow2v_res = []
i = 0

while i < len(p2_modules):
    code_vector = avg_feature_vector(p2_code[i])
    test_vector = avg_feature_vector(p2_test[i])
    res = ( p2_modules[i], 1 - spatial.distance.cosine(code_vector, test_vector) )
    p2_sow2v_res.append(res)
    i+=1
    
p2_res2_df = pd.DataFrame(p2_sow2v_res, columns=['P2 Module','W2V'])
p2_res2_df
# Out:
#       P2 Module       W2V
# 0   apm-commons  0.848267
# 1  apm-protocol  0.728598
# 2    apm-webapp  0.578733
# 3    oap-server  0.977532

# %%
p3_sow2v_res = []
i = 0

while i < len(p3_modules):
    code_vector = avg_feature_vector(p3_code[i])
    test_vector = avg_feature_vector(p3_test[i])
    res = ( p3_modules[i], 1 - spatial.distance.cosine(code_vector, test_vector) )
    p3_sow2v_res.append(res)
    i+=1
    
p3_res2_df = pd.DataFrame(p3_sow2v_res, columns=['P3 Module','W2V'])
p3_res2_df
# Out:
#                    P3 Module       W2V
# 0              flink-clients  0.978630
# 1           flink-connectors  0.981656
# 2            flink-container  0.787314
# 3              flink-contrib  0.721722
# 4                 flink-core  0.974657
# 5                 flink-docs  0.923784
# 6                 flink-dstl  0.922945
# 7             flink-examples  0.867055
# 8   flink-external-resources  0.793613
# 9          flink-filesystems  0.944907
# 10             flink-formats  0.973742
# 11                flink-java  0.966900
# 12          flink-kubernetes  0.990192
# 13           flink-libraries  0.967364
# 14             flink-metrics  0.976395
# 15           flink-optimizer  0.918391
# 16              flink-python  0.973605
# 17     flink-queryable-state  0.953088
# 18                 flink-rpc  0.982742
# 19             flink-runtime  0.988961
# 20         flink-runtime-web  0.975219
# 21               flink-scala  0.907065
# 22      flink-state-backends  0.992328
# ...

# %%
p4_sow2v_res = []
i = 0

while i < len(p4_modules):
    code_vector = avg_feature_vector(p4_code[i])
    test_vector = avg_feature_vector(p4_test[i])
    res = ( p4_modules[i], 1 - spatial.distance.cosine(code_vector, test_vector) )
    p4_sow2v_res.append(res)
    i+=1
    
p4_res2_df = pd.DataFrame(p4_sow2v_res, columns=['P4 Module','W2V'])
p4_res2_df
# Out:
#         P4 Module       W2V
# 0             acl  0.947038
# 1          broker  0.980006
# 2          client  0.960552
# 3          common  0.960870
# 4          filter  0.913330
# 5     logappender  0.693291
# 6         logging  0.853279
# 7         namesrv  0.965677
# 8   openmessaging  0.915092
# 9        remoting  0.911501
# 10        srvutil  0.625544
# 11          store  0.968264
# 12          tools  0.779609

# %%
p5_sow2v_res = []
i = 0

while i < len(p5_modules):
    code_vector = avg_feature_vector(p5_code[i])
    test_vector = avg_feature_vector(p5_test[i])
    res = ( p5_modules[i], 1 - spatial.distance.cosine(code_vector, test_vector) )
    p5_sow2v_res.append(res)
    i+=1
    
p5_res2_df = pd.DataFrame(p5_sow2v_res, columns=['P5 Module','W2V'])
p5_res2_df
# Out:
#                      P5 Module       W2V
# 0         shardingsphere-agent  0.964286
# 1   shardingsphere-db-protocol  0.982144
# 2      shardingsphere-features  0.983589
# 3         shardingsphere-infra  0.987668
# 4          shardingsphere-jdbc  0.974560
# 5        shardingsphere-kernel  0.971393
# 6          shardingsphere-mode  0.976041
# 7         shardingsphere-proxy  0.986355
# 8       shardingsphere-scaling  0.932304
# 9           shardingsphere-spi  0.915564
# 10   shardingsphere-sql-parser  0.926828

# %% [markdown]
# #### Cosine Similarity with SpaCy

# %%
def get_spacycos_sim(code, test):
    doc1 = nlp(code)
    doc2 = nlp(test)
    return doc1.similarity(doc2)

# %%
p1_spacy_res = []
i = 0

while i < len(p1_modules):
    result = ( p1_modules[i], get_spacycos_sim(p1_code[i], p1_test[i]) )
    p1_spacy_res.append(result)
    i+=1
    
p1_res3_df = pd.DataFrame(p1_spacy_res, columns=['P1 Module','SpaCy'])
p1_res3_df
# Out:
#               P1 Module     SpaCy
# 0         dubbo-cluster  0.964895
# 1          dubbo-common  0.976509
# 2      dubbo-compatible  0.965226
# 3          dubbo-config  0.966032
# 4    dubbo-configcenter  0.967799
# 5       dubbo-container  0.845197
# 6          dubbo-filter  0.914776
# 7        dubbo-metadata  0.977423
# 8         dubbo-monitor  0.966396
# 9          dubbo-plugin  0.973724
# 10       dubbo-registry  0.989546
# 11       dubbo-remoting  0.987527
# 12            dubbo-rpc  0.932247
# 13  dubbo-serialization  0.951517

# %%
p2_spacy_res = []
i = 0

while i < len(p2_modules):
    result = ( p2_modules[i], get_spacycos_sim(p2_code[i], p2_test[i]) )
    p2_spacy_res.append(result)
    i+=1
    
p2_res3_df = pd.DataFrame(p2_spacy_res, columns=['P2 Module','SpaCy'])
p2_res3_df
# Out:
#       P2 Module     SpaCy
# 0   apm-commons  0.938699
# 1  apm-protocol  0.886394
# 2    apm-webapp  0.726513
# 3    oap-server  0.992924

# %%
p3_spacy_res = []
i = 0

while i < len(p3_modules):
    result = ( p3_modules[i], get_spacycos_sim(p3_code[i], p3_test[i]) )
    p3_spacy_res.append(result)
    i+=1
    
p3_res3_df = pd.DataFrame(p3_spacy_res, columns=['P3 Module','SpaCy'])
p3_res3_df
# Out:
#                    P3 Module     SpaCy
# 0              flink-clients  0.989548
# 1           flink-connectors  0.991741
# 2            flink-container  0.867786
# 3              flink-contrib  0.886335
# 4                 flink-core  0.990289
# 5                 flink-docs  0.969877
# 6                 flink-dstl  0.955760
# 7             flink-examples  0.952552
# 8   flink-external-resources  0.915390
# 9          flink-filesystems  0.975037
# 10             flink-formats  0.984378
# 11                flink-java  0.986372
# 12          flink-kubernetes  0.994764
# 13           flink-libraries  0.978244
# 14             flink-metrics  0.985026
# 15           flink-optimizer  0.956160
# 16              flink-python  0.984300
# 17     flink-queryable-state  0.982195
# 18                 flink-rpc  0.988310
# 19             flink-runtime  0.996526
# 20         flink-runtime-web  0.988311
# 21               flink-scala  0.948153
# 22      flink-state-backends  0.994683
# ...

# %%
p4_spacy_res = []
i = 0

while i < len(p4_modules):
    result = ( p4_modules[i], get_spacycos_sim(p4_code[i], p4_test[i]) )
    p4_spacy_res.append(result)
    i+=1
    
p4_res3_df = pd.DataFrame(p4_spacy_res, columns=['P4 Module','SpaCy'])
p4_res3_df
# Out:
#         P4 Module     SpaCy
# 0             acl  0.974393
# 1          broker  0.988707
# 2          client  0.981157
# 3          common  0.977873
# 4          filter  0.928938
# 5     logappender  0.819567
# 6         logging  0.908512
# 7         namesrv  0.971123
# 8   openmessaging  0.968057
# 9        remoting  0.961831
# 10        srvutil  0.855719
# 11          store  0.978086
# 12          tools  0.920368

# %%
p5_spacy_res = []
i = 0

while i < len(p5_modules):
    result = ( p5_modules[i], get_spacycos_sim(p5_code[i], p5_test[i]) )
    p5_spacy_res.append(result)
    i+=1
    
p5_res3_df = pd.DataFrame(p5_spacy_res, columns=['P5 Module','SpaCy'])
p5_res3_df
# Out:
#                      P5 Module     SpaCy
# 0         shardingsphere-agent  0.983764
# 1   shardingsphere-db-protocol  0.992455
# 2      shardingsphere-features  0.994042
# 3         shardingsphere-infra  0.994136
# 4          shardingsphere-jdbc  0.985543
# 5        shardingsphere-kernel  0.989014
# 6          shardingsphere-mode  0.988309
# 7         shardingsphere-proxy  0.993981
# 8       shardingsphere-scaling  0.978789
# 9           shardingsphere-spi  0.946030
# 10   shardingsphere-sql-parser  0.960996

# %% [markdown]
# #### Cosine Similarity with FastText

# %%
from gensim.models.wrappers import FastText

ft_model = FastText.load_fasttext_format(r"C:\Users\biadge\OneDrive - BP\PhD\extraction\wiki.en")
# Out:
# WARNING:gensim.models.deprecated.word2vec:Slow version of gensim.models.deprecated.word2vec is being used
# INFO:gensim.models.deprecated.fasttext_wrapper:loading 2519370 words for fastText model from C:\Users\biadge\OneDrive - BP\PhD\extraction\wiki.en.bin
# INFO:gensim.models.deprecated.fasttext_wrapper:loading weights for 2519370 words for fastText model from C:\Users\biadge\OneDrive - BP\PhD\extraction\wiki.en.bin
# INFO:gensim.models.deprecated.fasttext_wrapper:loaded (2519370, 300) weight matrix for fastText model from C:\Users\biadge\OneDrive - BP\PhD\extraction\wiki.en.bin

# %%
def get_ft_sim(code, test):
    return ft_model.similarity(code, test)

# %%
p1_ft_res = []
i = 0

while i < len(p1_modules):
    result = ( p1_modules[i], get_ft_sim(p1_code[i],p1_test[i]) )
    p1_ft_res.append(result)
    i+=1
    
p1_res4_df = pd.DataFrame(p1_ft_res, columns=['P1 Module','FastText'])
p1_res4_df
# Out:
#               P1 Module  FastText
# 0         dubbo-cluster  0.988797
# 1          dubbo-common  0.991762
# 2      dubbo-compatible  0.981462
# 3          dubbo-config  0.987663
# 4    dubbo-configcenter  0.986640
# 5       dubbo-container  0.898441
# 6          dubbo-filter  0.966892
# 7        dubbo-metadata  0.983865
# 8         dubbo-monitor  0.988022
# 9          dubbo-plugin  0.986956
# 10       dubbo-registry  0.993761
# 11       dubbo-remoting  0.995420
# 12            dubbo-rpc  0.970338
# 13  dubbo-serialization  0.979342

# %%
p2_ft_res = []
i = 0

while i < len(p2_modules):
    result = ( p2_modules[i], get_ft_sim(p2_code[i],p2_test[i]) )
    p2_ft_res.append(result)
    i+=1
    
p2_res4_df = pd.DataFrame(p2_ft_res, columns=['P2 Module','FastText'])
p2_res4_df
# Out:
#       P2 Module  FastText
# 0   apm-commons  0.956030
# 1  apm-protocol  0.896623
# 2    apm-webapp  0.780178
# 3    oap-server  0.996289

# %%
p3_ft_res = []
i = 0

while i < len(p3_modules):
    result = ( p3_modules[i], get_ft_sim(p3_code[i],p3_test[i]) )
    p3_ft_res.append(result)
    i+=1
    
p3_res4_df = pd.DataFrame(p3_ft_res, columns=['P3 Module','FastText'])
p3_res4_df
# Out:
#                    P3 Module  FastText
# 0              flink-clients  0.994439
# 1           flink-connectors  0.997696
# 2            flink-container  0.958747
# 3              flink-contrib  0.944988
# 4                 flink-core  0.994689
# 5                 flink-docs  0.984142
# 6                 flink-dstl  0.973157
# 7             flink-examples  0.964492
# 8   flink-external-resources  0.927069
# 9          flink-filesystems  0.990610
# 10             flink-formats  0.988710
# 11                flink-java  0.988592
# 12          flink-kubernetes  0.995837
# 13           flink-libraries  0.992732
# 14             flink-metrics  0.993278
# 15           flink-optimizer  0.966847
# 16              flink-python  0.989807
# 17     flink-queryable-state  0.987197
# 18                 flink-rpc  0.992772
# 19             flink-runtime  0.998462
# 20         flink-runtime-web  0.988408
# 21               flink-scala  0.978952
# 22      flink-state-backends  0.996850
# ...

# %%
p4_ft_res = []
i = 0

while i < len(p4_modules):
    result = ( p4_modules[i], get_ft_sim(p4_code[i],p4_test[i]) )
    p4_ft_res.append(result)
    i+=1
    
p4_res4_df = pd.DataFrame(p4_ft_res, columns=['P4 Module','FastText'])
p4_res4_df
# Out:
#         P4 Module  FastText
# 0             acl  0.988050
# 1          broker  0.993851
# 2          client  0.991579
# 3          common  0.992626
# 4          filter  0.951361
# 5     logappender  0.904807
# 6         logging  0.949588
# 7         namesrv  0.987261
# 8   openmessaging  0.978029
# 9        remoting  0.982692
# 10        srvutil  0.899459
# 11          store  0.986323
# 12          tools  0.949977

# %%
p5_ft_res = []
i = 0

while i < len(p5_modules):
    result = ( p5_modules[i], get_ft_sim(p5_code[i],p5_test[i]) )
    p5_ft_res.append(result)
    i+=1
    
p5_res4_df = pd.DataFrame(p5_ft_res, columns=['P5 Module','FastText'])
p5_res4_df
# Out:
#                      P5 Module  FastText
# 0         shardingsphere-agent  0.989027
# 1   shardingsphere-db-protocol  0.995725
# 2      shardingsphere-features  0.996682
# 3         shardingsphere-infra  0.996927
# 4          shardingsphere-jdbc  0.994139
# 5        shardingsphere-kernel  0.993957
# 6          shardingsphere-mode  0.994671
# 7         shardingsphere-proxy  0.996260
# 8       shardingsphere-scaling  0.985497
# 9           shardingsphere-spi  0.949571
# 10   shardingsphere-sql-parser  0.981146

# %% [markdown]
# ### Text Similarity Summary (Code and Tests)

# %%
p1_summ_codetest_df = p1_res1_df.merge(p1_res2_df).merge(p1_res3_df).merge(p1_res4_df)
p1_summ_codetest_df
# Out:
#               P1 Module     TFIDF       W2V     SpaCy  FastText
# 0         dubbo-cluster  0.694818  0.931694  0.964895  0.988797
# 1          dubbo-common  0.608003  0.952701  0.976509  0.991762
# 2      dubbo-compatible  0.485747  0.906468  0.965226  0.981462
# 3          dubbo-config  0.517267  0.945942  0.966032  0.987663
# 4    dubbo-configcenter  0.686780  0.952474  0.967799  0.986640
# 5       dubbo-container  0.679380  0.851279  0.845197  0.898441
# 6          dubbo-filter  0.522603  0.848411  0.914776  0.966892
# 7        dubbo-metadata  0.682664  0.944727  0.977423  0.983865
# 8         dubbo-monitor  0.764186  0.932354  0.966396  0.988022
# 9          dubbo-plugin  0.493402  0.935700  0.973724  0.986956
# 10       dubbo-registry  0.901452  0.987535  0.989546  0.993761
# 11       dubbo-remoting  0.840885  0.976006  0.987527  0.995420
# 12            dubbo-rpc  0.280882  0.831779  0.932247  0.970338
# 13  dubbo-serialization  0.506218  0.896277  0.951517  0.979342

# %%
p2_summ_codetest_df = p2_res1_df.merge(p2_res2_df).merge(p2_res3_df).merge(p2_res4_df)
p2_summ_codetest_df
# Out:
#       P2 Module     TFIDF       W2V     SpaCy  FastText
# 0   apm-commons  0.326697  0.848267  0.938699  0.956030
# 1  apm-protocol  0.187707  0.728598  0.886394  0.896623
# 2    apm-webapp  0.042718  0.578733  0.726513  0.780178
# 3    oap-server  0.811193  0.977532  0.992924  0.996289

# %%
p3_summ_codetest_df = p3_res1_df.merge(p3_res2_df).merge(p3_res3_df).merge(p3_res4_df)
p3_summ_codetest_df
# Out:
#                    P3 Module     TFIDF       W2V     SpaCy  FastText
# 0              flink-clients  0.820911  0.978630  0.989548  0.994439
# 1           flink-connectors  0.824692  0.981656  0.991741  0.997696
# 2            flink-container  0.478378  0.787314  0.867786  0.958747
# 3              flink-contrib  0.216004  0.721722  0.886335  0.944988
# 4                 flink-core  0.829508  0.974657  0.990289  0.994689
# 5                 flink-docs  0.610350  0.923784  0.969877  0.984142
# 6                 flink-dstl  0.590040  0.922945  0.955760  0.973157
# 7             flink-examples  0.181599  0.867055  0.952552  0.964492
# 8   flink-external-resources  0.495939  0.793613  0.915390  0.927069
# 9          flink-filesystems  0.522374  0.944907  0.975037  0.990610
# 10             flink-formats  0.759770  0.973742  0.984378  0.988710
# 11                flink-java  0.653812  0.966900  0.986372  0.988592
# 12          flink-kubernetes  0.898674  0.990192  0.994764  0.995837
# ...

# %%
p4_summ_codetest_df = p4_res1_df.merge(p4_res2_df).merge(p4_res3_df).merge(p4_res4_df)
p4_summ_codetest_df
# Out:
#         P4 Module     TFIDF       W2V     SpaCy  FastText
# 0             acl  0.673354  0.947038  0.974393  0.988050
# 1          broker  0.822696  0.980006  0.988707  0.993851
# 2          client  0.755249  0.960552  0.981157  0.991579
# 3          common  0.560394  0.960870  0.977873  0.992626
# 4          filter  0.539869  0.913330  0.928938  0.951361
# 5     logappender  0.038362  0.693291  0.819567  0.904807
# 6         logging  0.521046  0.853279  0.908512  0.949588
# 7         namesrv  0.674293  0.965677  0.971123  0.987261
# 8   openmessaging  0.529480  0.915092  0.968057  0.978029
# 9        remoting  0.519058  0.911501  0.961831  0.982692
# 10        srvutil  0.136740  0.625544  0.855719  0.899459
# 11          store  0.761854  0.968264  0.978086  0.986323
# 12          tools  0.342913  0.779609  0.920368  0.949977

# %%
p5_summ_codetest_df = p5_res1_df.merge(p5_res2_df).merge(p5_res3_df).merge(p5_res4_df)
p5_summ_codetest_df
# Out:
#                      P5 Module     TFIDF       W2V     SpaCy  FastText
# 0         shardingsphere-agent  0.772023  0.964286  0.983764  0.989027
# 1   shardingsphere-db-protocol  0.941803  0.982144  0.992455  0.995725
# 2      shardingsphere-features  0.933575  0.983589  0.994042  0.996682
# 3         shardingsphere-infra  0.884716  0.987668  0.994136  0.996927
# 4          shardingsphere-jdbc  0.888897  0.974560  0.985543  0.994139
# 5        shardingsphere-kernel  0.747177  0.971393  0.989014  0.993957
# 6          shardingsphere-mode  0.812701  0.976041  0.988309  0.994671
# 7         shardingsphere-proxy  0.897779  0.986355  0.993981  0.996260
# 8       shardingsphere-scaling  0.769502  0.932304  0.978789  0.985497
# 9           shardingsphere-spi  0.601100  0.915564  0.946030  0.949571
# 10   shardingsphere-sql-parser  0.563670  0.926828  0.960996  0.981146

# %%
p1_summ_codetest_df.plot(kind='box', figsize=(4,7), ylim=(0.0, 1.0))
# Out:
# DEBUG:matplotlib:CONFIGDIR=C:\Users\biadge\.matplotlib
# DEBUG:matplotlib:(private) matplotlib data path: c:\users\biadge\appdata\local\programs\python\python37\lib\site-packages\matplotlib\mpl-data
# DEBUG:matplotlib:matplotlib data path: c:\users\biadge\appdata\local\programs\python\python37\lib\site-packages\matplotlib\mpl-data
# DEBUG:matplotlib:loaded rc file c:\users\biadge\appdata\local\programs\python\python37\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# DEBUG:matplotlib:matplotlib version 3.2.1
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is win32
# ...

# %%
p2_summ_codetest_df.plot(kind='box', figsize=(4,7), ylim=(0.0, 1.0))

# %%
p3_summ_codetest_df.plot(kind='box', figsize=(4,7), ylim=(0.0, 1.0))

# %%
p4_summ_codetest_df.plot(kind='box', figsize=(4,7), ylim=(0.0, 1.0))

# %%
p5_summ_codetest_df.plot(kind='box', figsize=(4,7), ylim=(0.0, 1.0))

# %%
# print(p1_jaccard_res.mean())
# print(p2_jaccard_res.mean())
# print(p1_tfidf_res.mean())
# print(p2_tfidf_res.mean())
# print(p1_sow2v_res.mean())
# print(p2_sow2v_res.mean())

# %%
p1_summ_codetest_df.to_csv("output/p1_summ_codetest_df.csv", index=False)
p2_summ_codetest_df.to_csv("output/p2_summ_codetest_df.csv", index=False)
p3_summ_codetest_df.to_csv("output/p3_summ_codetest_df.csv", index=False)
p4_summ_codetest_df.to_csv("output/p4_summ_codetest_df.csv", index=False)
p5_summ_codetest_df.to_csv("output/p5_summ_codetest_df.csv", index=False)

# %% [markdown]
# ### 2 - CODE/DOC and TEST/DOC Similarity

# %%
p1_full_code = ' '.join([str(item) for item in p1_code])
p2_full_code = ' '.join([str(item) for item in p2_code])
p3_full_code = ' '.join([str(item) for item in p3_code])
p4_full_code = ' '.join([str(item) for item in p4_code])
p5_full_code = ' '.join([str(item) for item in p5_code])

# %%
p1_full_test = ' '.join([str(item) for item in p1_test])
p2_full_test = ' '.join([str(item) for item in p2_test])
p3_full_test = ' '.join([str(item) for item in p3_test])
p4_full_test = ' '.join([str(item) for item in p4_test])
p5_full_test = ' '.join([str(item) for item in p5_test])

# %% [markdown]
# #### Cosine Similarity with TFIDF Vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer()
p1_tfidf_codedoc = tfidf_vectorizer.fit_transform([p1_full_code,p1_doc])

tfidf_vectorizer = TfidfVectorizer()
p1_tfidf_testdoc = tfidf_vectorizer.fit_transform([p1_full_test,p1_doc])

# %%
tfidf_vectorizer = TfidfVectorizer()
p2_tfidf_codedoc = tfidf_vectorizer.fit_transform([p2_full_code,p2_doc])

tfidf_vectorizer = TfidfVectorizer()
p2_tfidf_testdoc = tfidf_vectorizer.fit_transform([p2_full_test,p2_doc])

# %%
tfidf_vectorizer = TfidfVectorizer()
p3_tfidf_codedoc = tfidf_vectorizer.fit_transform([p3_full_code,p3_doc])

tfidf_vectorizer = TfidfVectorizer()
p3_tfidf_testdoc = tfidf_vectorizer.fit_transform([p3_full_test,p3_doc])

# %%
tfidf_vectorizer = TfidfVectorizer()
p4_tfidf_codedoc = tfidf_vectorizer.fit_transform([p4_full_code,p4_doc])

tfidf_vectorizer = TfidfVectorizer()
p4_tfidf_testdoc = tfidf_vectorizer.fit_transform([p4_full_test,p4_doc])

# %%
tfidf_vectorizer = TfidfVectorizer()
p5_tfidf_codedoc = tfidf_vectorizer.fit_transform([p5_full_code,p5_doc])

tfidf_vectorizer = TfidfVectorizer()
p5_tfidf_testdoc = tfidf_vectorizer.fit_transform([p5_full_test,p5_doc])

# %%
p1_tfidf_codedoc
# Out:
# <2x1486 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1561 stored elements in Compressed Sparse Row format>

# %%
from sklearn.metrics.pairwise import cosine_similarity

def get_cos_sim(code, test):
    return cosine_similarity(code, test)

# %%
p1_tfidf_codedoc_res = get_cos_sim(p1_tfidf_codedoc, p1_tfidf_codedoc)[0][1].round(3)
p1_tfidf_codedoc_res
# Out:
# 0.106

# %%
p1_tfidf_testdoc_res = get_cos_sim(p1_tfidf_testdoc, p1_tfidf_testdoc)[0][1].round(3)
p1_tfidf_testdoc_res
# Out:
# 0.083

# %%
p2_tfidf_codedoc_res = get_cos_sim(p2_tfidf_codedoc, p2_tfidf_codedoc)[0][1].round(3)
p2_tfidf_codedoc_res
# Out:
# 0.241

# %%
p2_tfidf_testdoc_res = get_cos_sim(p2_tfidf_testdoc, p2_tfidf_testdoc)[0][1].round(3)
p2_tfidf_testdoc_res
# Out:
# 0.163

# %%
p3_tfidf_codedoc_res = get_cos_sim(p3_tfidf_codedoc, p3_tfidf_codedoc)[0][1].round(3)
p3_tfidf_codedoc_res
# Out:
# 0.08

# %%
p3_tfidf_testdoc_res = get_cos_sim(p3_tfidf_testdoc, p3_tfidf_testdoc)[0][1].round(3)
p3_tfidf_testdoc_res
# Out:
# 0.098

# %%
p4_tfidf_codedoc_res = get_cos_sim(p4_tfidf_codedoc, p4_tfidf_codedoc)[0][1].round(3)
p4_tfidf_codedoc_res
# Out:
# 0.143

# %%
p4_tfidf_testdoc_res = get_cos_sim(p4_tfidf_testdoc, p4_tfidf_testdoc)[0][1].round(3)
p4_tfidf_testdoc_res
# Out:
# 0.116

# %%
p5_tfidf_codedoc_res = get_cos_sim(p5_tfidf_codedoc, p5_tfidf_codedoc)[0][1].round(3)
p5_tfidf_codedoc_res
# Out:
# 0.117

# %%
p5_tfidf_testdoc_res = get_cos_sim(p5_tfidf_testdoc, p5_tfidf_testdoc)[0][1].round(3)
p5_tfidf_testdoc_res
# Out:
# 0.129

# %%
summ_tfidf_doc_df = pd.DataFrame(np.transpose([['P1', 'P2', 'P3', 'P4', 'P5'],[p1_tfidf_codedoc_res, p2_tfidf_codedoc_res, p3_tfidf_codedoc_res, p4_tfidf_codedoc_res, p5_tfidf_codedoc_res]]), columns=['Project', 'CODE/DOC TFIDF'])
summ_tfidf_doc_df['TEST/DOC TFIDF'] = [p1_tfidf_testdoc_res, p2_tfidf_testdoc_res, p3_tfidf_testdoc_res, p4_tfidf_testdoc_res, p5_tfidf_testdoc_res]
summ_tfidf_doc_df = summ_tfidf_doc_df.set_index('Project')
summ_tfidf_doc_df
# Out:
#         CODE/DOC TFIDF  TEST/DOC TFIDF
# Project
# P1               0.106           0.083
# P2               0.241           0.163
# P3                0.08           0.098
# P4               0.143           0.116
# P5               0.117           0.129

# %% [markdown]
# #### Cosine Similarity with Averaged Word2Vec

# %%
from gensim.models.keyedvectors import KeyedVectors
from nltk import word_tokenize

so_w2v_model = KeyedVectors.load_word2vec_format('C:/Users/biadge/OneDrive - BP/PhD/extraction/SO_vectors_200.bin', binary=True)
# Out:
# INFO:gensim.models.utils_any2vec:loading projection weights from C:/Users/biadge/OneDrive - BP/PhD/extraction/SO_vectors_200.bin
# DEBUG:smart_open.smart_open_lib:{'uri': 'C:/Users/biadge/OneDrive - BP/PhD/extraction/SO_vectors_200.bin', 'mode': 'rb', 'buffering': -1, 'encoding': None, 'errors': None, 'newline': None, 'closefd': True, 'opener': None, 'ignore_ext': False, 'transport_params': None}
# INFO:gensim.models.utils_any2vec:loaded (1787145, 200) matrix from C:/Users/biadge/OneDrive - BP/PhD/extraction/SO_vectors_200.bin

# %%
import numpy as np
from scipy import spatial

index2word_set = set(so_w2v_model.index2word)

def avg_feature_vector(sentence, model=so_w2v_model, num_features=200, index2word_set=index2word_set):
    words = sentence.split()
    feature_vec = np.zeros((num_features, ), dtype='float32')
    n_words = 0
    for word in words:
        if word in index2word_set:
            n_words += 1
            feature_vec = np.add(feature_vec, model[word])
    if (n_words > 0):
        feature_vec = np.divide(feature_vec, n_words)
    return feature_vec

# %%
code_vector = avg_feature_vector(p1_full_code)
test_vector = avg_feature_vector(p1_full_test)
doc_vector = avg_feature_vector(p1_doc)
p1_sow2v_codedoc_res = (1 - spatial.distance.cosine(code_vector, doc_vector)).round(3)
p1_sow2v_testdoc_res = (1 - spatial.distance.cosine(test_vector, doc_vector)).round(3)
p1_sow2v_codedoc_res, p1_sow2v_testdoc_res
# Out:
# (0.583, 0.531)

# %%
code_vector = avg_feature_vector(p2_full_code)
test_vector = avg_feature_vector(p2_full_test)
doc_vector = avg_feature_vector(p2_doc)
p2_sow2v_codedoc_res = (1 - spatial.distance.cosine(code_vector, doc_vector)).round(3)
p2_sow2v_testdoc_res = (1 - spatial.distance.cosine(test_vector, doc_vector)).round(3)
p2_sow2v_codedoc_res, p2_sow2v_testdoc_res
# Out:
# (0.76, 0.775)

# %%
code_vector = avg_feature_vector(p3_full_code)
test_vector = avg_feature_vector(p3_full_test)
doc_vector = avg_feature_vector(p3_doc)
p3_sow2v_codedoc_res = (1 - spatial.distance.cosine(code_vector, doc_vector)).round(3)
p3_sow2v_testdoc_res = (1 - spatial.distance.cosine(test_vector, doc_vector)).round(3)
p3_sow2v_codedoc_res, p3_sow2v_testdoc_res
# Out:
# (0.511, 0.561)

# %%
code_vector = avg_feature_vector(p4_full_code)
test_vector = avg_feature_vector(p4_full_test)
doc_vector = avg_feature_vector(p4_doc)
p4_sow2v_codedoc_res = (1 - spatial.distance.cosine(code_vector, doc_vector)).round(3)
p4_sow2v_testdoc_res = (1 - spatial.distance.cosine(test_vector, doc_vector)).round(3)
p4_sow2v_codedoc_res, p4_sow2v_testdoc_res
# Out:
# (0.633, 0.661)

# %%
code_vector = avg_feature_vector(p5_full_code)
test_vector = avg_feature_vector(p5_full_test)
doc_vector = avg_feature_vector(p5_doc)
p5_sow2v_codedoc_res = (1 - spatial.distance.cosine(code_vector, doc_vector)).round(3)
p5_sow2v_testdoc_res = (1 - spatial.distance.cosine(test_vector, doc_vector)).round(3)
p5_sow2v_codedoc_res, p5_sow2v_testdoc_res
# Out:
# (0.594, 0.623)

# %%
summ_sow2v_doc_df = pd.DataFrame(np.transpose([['P1', 'P2', 'P3', 'P4', 'P5'],[p1_sow2v_codedoc_res, p2_sow2v_codedoc_res, p3_sow2v_codedoc_res, p4_sow2v_codedoc_res, p5_sow2v_codedoc_res]]), columns=['Project', 'CODE/DOC SO W2V'])
summ_sow2v_doc_df['TEST/DOC SO W2V'] = [p1_sow2v_testdoc_res, p2_sow2v_testdoc_res, p3_sow2v_testdoc_res, p4_sow2v_testdoc_res, p5_sow2v_testdoc_res]
summ_sow2v_doc_df = summ_sow2v_doc_df.set_index('Project')
summ_sow2v_doc_df
# Out:
#         CODE/DOC SO W2V  TEST/DOC SO W2V
# Project
# P1                0.583            0.531
# P2                 0.76            0.775
# P3                0.511            0.561
# P4                0.633            0.661
# P5                0.594            0.623

# %% [markdown]
# #### Cosine Similarity with SpaCy

# %%
def get_spacycos_sim(x, y):
    doc1 = nlp(x)
    doc2 = nlp(y)
    return doc1.similarity(doc2)

# %%
p1_spacy_codedoc_res = get_spacycos_sim(p1_full_code, p1_doc).round(3)
p1_spacy_testdoc_res = get_spacycos_sim(p1_full_test, p1_doc).round(3)
p1_spacy_codedoc_res, p1_spacy_testdoc_res
# Out:
# (0.881, 0.889)

# %%
p2_spacy_codedoc_res = get_spacycos_sim(p2_full_code, p2_doc).round(3)
p2_spacy_testdoc_res = get_spacycos_sim(p2_full_test, p2_doc).round(3)
p2_spacy_codedoc_res, p2_spacy_testdoc_res
# Out:
# (0.934, 0.934)

# %%
p3_spacy_codedoc_res = get_spacycos_sim(p3_full_code, p3_doc).round(3)
p3_spacy_testdoc_res = get_spacycos_sim(p3_full_test, p3_doc).round(3)
p3_spacy_codedoc_res, p3_spacy_testdoc_res
# Out:
# (0.882, 0.895)

# %%
p4_spacy_codedoc_res = get_spacycos_sim(p4_full_code, p4_doc).round(3)
p4_spacy_testdoc_res = get_spacycos_sim(p4_full_test, p4_doc).round(3)
p4_spacy_codedoc_res, p4_spacy_testdoc_res
# Out:
# (0.892, 0.905)

# %%
p5_spacy_codedoc_res = get_spacycos_sim(p5_full_code, p5_doc).round(3)
p5_spacy_testdoc_res = get_spacycos_sim(p5_full_test, p5_doc).round(3)
p5_spacy_codedoc_res, p5_spacy_testdoc_res
# Out:
# (0.894, 0.899)

# %%
summ_spacy_doc_df = pd.DataFrame(np.transpose([['P1', 'P2', 'P3', 'P4', 'P5'],[p1_spacy_codedoc_res, p2_spacy_codedoc_res, p3_spacy_codedoc_res, p4_spacy_codedoc_res, p5_spacy_codedoc_res]]), columns=['Project', 'CODE/DOC SPACY'])
summ_spacy_doc_df['TEST/DOC SPACY'] = [p1_spacy_testdoc_res, p2_spacy_testdoc_res, p3_spacy_testdoc_res, p4_spacy_testdoc_res, p5_spacy_testdoc_res]
summ_spacy_doc_df = summ_spacy_doc_df.set_index('Project')
summ_spacy_doc_df
# Out:
#         CODE/DOC SPACY  TEST/DOC SPACY
# Project
# P1               0.881           0.889
# P2               0.934           0.934
# P3               0.882           0.895
# P4               0.892           0.905
# P5               0.894           0.899

# %% [markdown]
# #### Cosine Similarity with FastText

# %%
from gensim.models.wrappers import FastText

ft_model = FastText.load_fasttext_format(r"C:\Users\biadge\OneDrive - BP\PhD\extraction\wiki.en")
# Out:
# WARNING:gensim.models.deprecated.word2vec:Slow version of gensim.models.deprecated.word2vec is being used
# INFO:gensim.models.deprecated.fasttext_wrapper:loading 2519370 words for fastText model from C:\Users\biadge\OneDrive - BP\PhD\extraction\wiki.en.bin
# INFO:gensim.models.deprecated.fasttext_wrapper:loading weights for 2519370 words for fastText model from C:\Users\biadge\OneDrive - BP\PhD\extraction\wiki.en.bin
# INFO:gensim.models.deprecated.fasttext_wrapper:loaded (2519370, 300) weight matrix for fastText model from C:\Users\biadge\OneDrive - BP\PhD\extraction\wiki.en.bin

# %%
def get_ft_sim(x, y):
    return ft_model.similarity(x, y)

# %%
p1_ft_codedoc_res = get_ft_sim(p1_full_code, p1_doc).round(3)
p1_ft_testdoc_res = get_ft_sim(p1_full_test, p1_doc).round(3)
p1_ft_codedoc_res, p1_ft_testdoc_res
# Out:
# (0.957, 0.957)

# %%
p2_ft_codedoc_res = get_ft_sim(p2_full_code, p2_doc).round(3)
p2_ft_testdoc_res = get_ft_sim(p2_full_test, p2_doc).round(3)
p2_ft_codedoc_res, p2_ft_testdoc_res
# Out:
# (0.967, 0.96)

# %%
p3_ft_codedoc_res = get_ft_sim(p3_full_code, p3_doc).round(3)
p3_ft_testdoc_res = get_ft_sim(p3_full_test, p3_doc).round(3)
p3_ft_codedoc_res, p3_ft_testdoc_res
# Out:
# (0.958, 0.963)

# %%
p4_ft_codedoc_res = get_ft_sim(p4_full_code, p4_doc).round(3)
p4_ft_testdoc_res = get_ft_sim(p4_full_test, p4_doc).round(3)
p4_ft_codedoc_res, p4_ft_testdoc_res
# Out:
# (0.963, 0.964)

# %%
p5_ft_codedoc_res = get_ft_sim(p5_full_code, p5_doc).round(3)
p5_ft_testdoc_res = get_ft_sim(p5_full_test, p5_doc).round(3)
p5_ft_codedoc_res, p5_ft_testdoc_res
# Out:
# (0.967, 0.968)

# %%
summ_ft_doc_df = pd.DataFrame(np.transpose([['P1', 'P2', 'P3', 'P4', 'P5'],[p1_ft_codedoc_res, p2_ft_codedoc_res, p3_ft_codedoc_res, p4_ft_codedoc_res, p5_ft_codedoc_res]]), columns=['Project', 'CODE/DOC FT'])
summ_ft_doc_df['TEST/DOC FT'] = [p1_ft_testdoc_res, p2_ft_testdoc_res, p3_ft_testdoc_res, p4_ft_testdoc_res, p5_ft_testdoc_res]
summ_ft_doc_df = summ_ft_doc_df.set_index('Project')
summ_ft_doc_df
# Out:
#         CODE/DOC FT  TEST/DOC FT
# Project
# P1            0.957        0.957
# P2            0.967        0.960
# P3            0.958        0.963
# P4            0.963        0.964
# P5            0.967        0.968

# %% [markdown]
# ### Text Similarity Summary (CODE/DOC and TEST/DOC)

# %%
summ_doc_df = summ_tfidf_doc_df.merge(summ_sow2v_doc_df, on='Project').merge(summ_spacy_doc_df, on='Project').merge(summ_ft_doc_df, on='Project')
summ_doc_df = summ_doc_df.astype(float)
summ_doc_df
# Out:
#          CODE/DOC TFIDF  TEST/DOC TFIDF  CODE/DOC SO W2V  TEST/DOC SO W2V  \
# Project
# P1                0.106           0.083            0.583            0.531
# P2                0.241           0.163            0.760            0.775
# P3                0.080           0.098            0.511            0.561
# P4                0.143           0.116            0.633            0.661
# P5                0.117           0.129            0.594            0.623
#
#          CODE/DOC SPACY  TEST/DOC SPACY  CODE/DOC FT  TEST/DOC FT
# Project
# P1                0.881           0.889        0.957        0.957
# P2                0.934           0.934        0.967        0.960
# P3                0.882           0.895        0.958        0.963
# P4                0.892           0.905        0.963        0.964
# P5                0.894           0.899        0.967        0.968

# %%
summ_code_doc_df = summ_doc_df[['CODE/DOC TFIDF', 'CODE/DOC SO W2V', 'CODE/DOC SPACY', 'CODE/DOC FT']]
summ_code_doc_df
# Out:
#          CODE/DOC TFIDF  CODE/DOC SO W2V  CODE/DOC SPACY  CODE/DOC FT
# Project
# P1                0.106            0.583           0.881        0.957
# P2                0.241            0.760           0.934        0.967
# P3                0.080            0.511           0.882        0.958
# P4                0.143            0.633           0.892        0.963
# P5                0.117            0.594           0.894        0.967

# %%
summ_test_doc_df = summ_doc_df[['TEST/DOC TFIDF', 'TEST/DOC SO W2V', 'TEST/DOC SPACY', 'TEST/DOC FT']]
summ_test_doc_df
# Out:
#          TEST/DOC TFIDF  TEST/DOC SO W2V  TEST/DOC SPACY  TEST/DOC FT
# Project
# P1                0.083            0.531           0.889        0.957
# P2                0.163            0.775           0.934        0.960
# P3                0.098            0.561           0.895        0.963
# P4                0.116            0.661           0.905        0.964
# P5                0.129            0.623           0.899        0.968

# %%
summ_code_doc_df.to_csv("output/summ_code_doc_df.csv", index=True)
summ_test_doc_df.to_csv("output/summ_test_doc_df.csv", index=True)

# %% [markdown]
# ### 3 - Graph out the correlation for CODE/DOC and TEST/DOC for each vectorisation

# %%
import matplotlib.pyplot as plt

ax1 = summ_doc_df.plot(kind='scatter', x='TEST/DOC TFIDF', y='CODE/DOC TFIDF', xlim=(0.0, 1.0), ylim=(0.0, 1.0), color='red', label='TFIDF')
ax2 = summ_doc_df.plot(kind='scatter', x='TEST/DOC SO W2V', y='CODE/DOC SO W2V', xlim=(0.0, 1.0), ylim=(0.0, 1.0), color='blue', label='SO W2V', ax=ax1)
ax3 = summ_doc_df.plot(kind='scatter', x='TEST/DOC SPACY', y='CODE/DOC SPACY', xlim=(0.0, 1.0), ylim=(0.0, 1.0), color='green', label='SPACY', ax=ax2)
ax4 = summ_doc_df.plot(kind='scatter', x='TEST/DOC FT', y='CODE/DOC FT', xlim=(0.0, 1.0), ylim=(0.0, 1.0), color='orange', label='FT', ax=ax3)
ax4.set_xlabel("TEST/DOC SIM")
ax4.set_ylabel("CODE/DOC SIM")
plt.show()

# %%
from scipy import stats

tfidf_pearson_score = stats.pearsonr(summ_doc_df['CODE/DOC TFIDF'], summ_doc_df['TEST/DOC TFIDF'])
tfidf_pearson_score
# Out:
# (0.8735315287646696, 0.052953196250551816)

# %%
sow2v_pearson_score = stats.pearsonr(summ_doc_df['CODE/DOC SO W2V'], summ_doc_df['TEST/DOC SO W2V'])
sow2v_pearson_score
# Out:
# (0.914320339867974, 0.029715891157627055)

# %%
spacy_pearson_score = stats.pearsonr(summ_doc_df['CODE/DOC SPACY'], summ_doc_df['TEST/DOC SPACY'])
spacy_pearson_score
# Out:
# (0.9823381321954322, 0.002810184811226775)

# %%
ft_pearson_score = stats.pearsonr(summ_doc_df['CODE/DOC FT'], summ_doc_df['TEST/DOC FT'])
ft_pearson_score
# Out:
# (0.5312047925132908, 0.35696199923042377)

# %%
corr_df = pd.DataFrame([tfidf_pearson_score, sow2v_pearson_score, spacy_pearson_score, ft_pearson_score], columns=['correlation coefficient', 'p-value'])
corr_df['vectorisation'] = ['TFIDF', 'SO W2V', 'SPACY', 'FT']
corr_df = corr_df.set_index('vectorisation')
corr_df
# Out:
#                correlation coefficient   p-value
# vectorisation
# TFIDF                         0.873532  0.052953
# SO W2V                        0.914320  0.029716
# SPACY                         0.982338  0.002810
# FT                            0.531205  0.356962

# %% [raw]
# ### 4 - Topic Modeling in Outliers (for modules):

# %% [markdown]
# P1 Spacy:
# - dubbo-container
#
# P1 FT:
# - dubbo-filter
#
# P3 TFIDF:
# - flink-streaming-scala
#
# P3 W2V:
# - flink-streaming-scala
# - flink-contrib
# - flink-container
#
# P3 Spacy:
# - flink-streaming-scala
# - flink-contrib
# - flink-container
#
# P3 FT:
# - flink-streaming-scala
# - flink-external-resources
# - flink-container
#
# P4 TFIDF:
# - logappender
# - srvutil
#
# P4 W2V:
# - logappender
#
# P4 Spacy:
# - logappender
#
# P5 Spacy:
# - shardingsphere-spi
# - shardingsphere-sql-parser
# - shardingsphere-scaling
#
# P5 FT:
# - shardingsphere-spi

# %%
p1_outliers = p1_data_df[p1_data_df['P1 Module'].isin(['dubbo-container', 'dubbo-filter'])]
p1_outliers
# Out:
#          P1 Module                                    Code Extraction  \
# 5  dubbo-container  container,container key shutdown hook key logg...
# 6     dubbo-filter  cache,cache factory,cache filter filter cache ...
#
#   Code Length                                    Test Extraction Test Length  \
# 5          64  container container,logback container logger l...          14
# 6         474  cache filter rpc invocation invocation cache f...         183
#
#                                       Doc Extraction
# 5  project highperformance javabased opensource r...
# 6  project highperformance javabased opensource r...

# %%
p3_outliers = p3_data_df[p3_data_df['P3 Module'].isin(['flink-streaming-scala', 'flink-contrib', 'flink-container', 'flink-external-resources'])]
p3_outliers
# Out:
#                    P3 Module  \
# 2            flink-container
# 3              flink-contrib
# 8   flink-external-resources
# 24     flink-streaming-scala
#
#                                       Code Extraction Code Length  \
# 2   standalone application cluster configuration p...          67
# 3   wikipedia edit event timestamp channel title d...         209
# 8   gpu driver external resource driver logger log...          61
# 24  scala product field accessor factory scala pro...          66
#
#                                       Test Extraction Test Length  \
# 2   standalone application cluster configuration p...          62
# 3   wikipedia edit source logger log logger logger...          56
# 8   gpu discovery script logger script path non co...          51
# 24  csv output format result path create path path...          62
#
#                                        Doc Extraction
# 2   open source stream processing framework powerf...
# ...

# %%
p4_outliers = p4_data_df[p4_data_df['P4 Module'].isin(['logappender', 'srvutil'])]
p4_outliers
# Out:
#       P4 Module                                    Code Extraction  \
# 5   logappender  producer instance appender type appender type ...
# 10      srvutil  watch service service thread internal logger l...
#
#    Code Length                                    Test Extraction Test Length  \
# 5          225  copy write array list message message copy wri...          40
# 10          90  watch service temporary folder temp folder tem...          35
#
#                                        Doc Extraction
# 5   distribute messaging streaming platform low la...
# 10  distribute messaging streaming platform low la...

# %%
p5_outliers = p5_data_df[p5_data_df['P5 Module'].isin(['shardingsphere-spi', 'shardingsphere-sql-parser', 'shardingsphere-scaling'])]
p5_outliers
# Out:
#                     P5 Module  \
# 8      shardingsphere-scaling
# 9          shardingsphere-spi
# 10  shardingsphere-sql-parser
#
#                                       Code Extraction Code Length  \
# 8   sql scale entry scale entry sql inventory dump...        1067
# 9   sharding sphere service loader map collection ...         195
# 10  sql lexer sql statement lexer sql lexer sql le...       19867
#
#                                       Test Extraction Test Length  \
# 8   sql scale entry scale entry database type ille...         259
# 9   sharding sphere service loader singleton servi...         178
# 10  sql format collection unit link list input sql...        1676
#
#                                        Doc Extraction
# 8   building criterion ecosystem multimodel databa...
# 9   building criterion ecosystem multimodel databa...
# 10  building criterion ecosystem multimodel databa...

# %%
p1_outliers['Code Extraction'] = p1_outliers['Code Extraction'].apply(lambda x: x.split(','))
p1_outliers['Test Extraction'] = p1_outliers['Test Extraction'].apply(lambda x: x.split(','))
p1_outliers['Code Extraction'] = p1_outliers['Code Extraction'].apply(lambda x: [y.split() for y in x])
p1_outliers['Test Extraction'] = p1_outliers['Test Extraction'].apply(lambda x: [y.split() for y in x])

p1_outliers = p1_outliers.drop(columns=['Code Length', 'Test Length', 'Doc Extraction'])
# Out:
# c:\users\biadge\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\users\biadge\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\users\biadge\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
p1_outliers
# Out:
#          P1 Module                                    Code Extraction  \
# 5  dubbo-container  [[container], [container, key, shutdown, hook,...
# 6     dubbo-filter  [[cache], [cache, factory], [cache, filter, fi...
#
#                                      Test Extraction
# 5  [[container, container], [logback, container, ...
# 6  [[cache, filter, rpc, invocation, invocation, ...

# %%
p3_outliers['Code Extraction'] = p3_outliers['Code Extraction'].apply(lambda x: x.split(','))
p3_outliers['Test Extraction'] = p3_outliers['Test Extraction'].apply(lambda x: x.split(','))
p3_outliers['Code Extraction'] = p3_outliers['Code Extraction'].apply(lambda x: [y.split() for y in x])
p3_outliers['Test Extraction'] = p3_outliers['Test Extraction'].apply(lambda x: [y.split() for y in x])

p3_outliers = p3_outliers.drop(columns=['Code Length', 'Test Length', 'Doc Extraction'])
# Out:
# c:\users\biadge\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\users\biadge\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\users\biadge\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
p4_outliers['Code Extraction'] = p4_outliers['Code Extraction'].apply(lambda x: x.split(','))
p4_outliers['Test Extraction'] = p4_outliers['Test Extraction'].apply(lambda x: x.split(','))
p4_outliers['Code Extraction'] = p4_outliers['Code Extraction'].apply(lambda x: [y.split() for y in x])
p4_outliers['Test Extraction'] = p4_outliers['Test Extraction'].apply(lambda x: [y.split() for y in x])

p4_outliers = p4_outliers.drop(columns=['Code Length', 'Test Length', 'Doc Extraction'])
# Out:
# c:\users\biadge\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\users\biadge\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\users\biadge\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
p5_outliers['Code Extraction'] = p5_outliers['Code Extraction'].apply(lambda x: x.split(','))
p5_outliers['Test Extraction'] = p5_outliers['Test Extraction'].apply(lambda x: x.split(','))
p5_outliers['Code Extraction'] = p5_outliers['Code Extraction'].apply(lambda x: [y.split() for y in x])
p5_outliers['Test Extraction'] = p5_outliers['Test Extraction'].apply(lambda x: [y.split() for y in x])

p5_outliers = p5_outliers.drop(columns=['Code Length', 'Test Length', 'Doc Extraction'])
# Out:
# c:\users\biadge\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\users\biadge\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\users\biadge\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
import gensim
import gensim.corpora as corpora
from gensim.models import CoherenceModel

def generate_lda(corpus_in, num_topics):
    id2word = corpora.Dictionary(corpus_in)
    corpus = [id2word.doc2bow(text) for text in corpus_in]
    
    lda_model =  gensim.models.LdaMulticore(corpus=corpus, 
                                        num_topics=num_topics,
                                        random_state=42,
                                        id2word=id2word, 
                                        alpha=0.01,
                                        passes=10,
                                        per_word_topics=True,
                                        workers=2)
    
    coherence_model_lda = CoherenceModel(model=lda_model, texts=corpus_in, dictionary=id2word, coherence='c_v')
    coherence_lda = coherence_model_lda.get_coherence()
    
    return lda_model, coherence_lda

# %%
p1_lda_code_res = []
p1_lda_test_res = []

for ce_data in p1_outliers['Code Extraction']:
    lm, coh_score = generate_lda(ce_data, 5)
    p1_lda_code_res.append((lm, coh_score))
    
for te_data in p1_outliers['Test Extraction']:
    lm, coh_score = generate_lda(te_data, 5)
    p1_lda_test_res.append((lm, coh_score))
# Out:
# INFO:gensim.corpora.dictionary:adding document #0 to Dictionary(0 unique tokens: [])
# INFO:gensim.corpora.dictionary:built Dictionary(24 unique tokens: ['container', 'condition', 'extension', 'hook', 'key']...) from 5 documents (total 64 corpus positions)
# INFO:gensim.models.ldamodel:using symmetric eta at 0.2
# INFO:gensim.models.ldamodel:using serial LDA version on this node
# INFO:gensim.models.ldamulticore:running online LDA training, 5 topics, 10 passes over the supplied corpus of 5 documents, updating every 4000 documents, evaluating every ~5 documents, iterating 50x with a convergence threshold of 0.001000
# INFO:gensim.models.ldamulticore:training LDA model using 2 processes
# INFO:gensim.models.ldamulticore:PROGRESS: pass 0, dispatched chunk #0 = documents up to #5/5, outstanding queue size 1
# DEBUG:gensim.models.ldamodel:updating topics
# ...

# %%
p3_lda_code_res = []
p3_lda_test_res = []

for ce_data in p3_outliers['Code Extraction']:
    lm, coh_score = generate_lda(ce_data, 5)
    p3_lda_code_res.append((lm, coh_score))
    
for te_data in p3_outliers['Test Extraction']:
    lm, coh_score = generate_lda(te_data, 5)
    p3_lda_test_res.append((lm, coh_score))
# Out:
# INFO:gensim.corpora.dictionary:adding document #0 to Dictionary(0 unique tokens: [])
# INFO:gensim.corpora.dictionary:built Dictionary(24 unique tokens: ['application', 'cause', 'cluster', 'command', 'configuration']...) from 2 documents (total 67 corpus positions)
# INFO:gensim.models.ldamodel:using symmetric eta at 0.2
# INFO:gensim.models.ldamodel:using serial LDA version on this node
# INFO:gensim.models.ldamulticore:running online LDA training, 5 topics, 10 passes over the supplied corpus of 2 documents, updating every 4000 documents, evaluating every ~2 documents, iterating 50x with a convergence threshold of 0.001000
# INFO:gensim.models.ldamulticore:training LDA model using 2 processes
# INFO:gensim.models.ldamulticore:PROGRESS: pass 0, dispatched chunk #0 = documents up to #2/2, outstanding queue size 1
# DEBUG:gensim.models.ldamodel:updating topics
# ...

# %%
p4_lda_code_res = []
p4_lda_test_res = []

for ce_data in p4_outliers['Code Extraction']:
    lm, coh_score = generate_lda(ce_data, 5)
    p4_lda_code_res.append((lm, coh_score))
    
for te_data in p4_outliers['Test Extraction']:
    lm, coh_score = generate_lda(te_data, 5)
    p4_lda_test_res.append((lm, coh_score))
# Out:
# INFO:gensim.corpora.dictionary:adding document #0 to Dictionary(0 unique tokens: [])
# INFO:gensim.corpora.dictionary:built Dictionary(43 unique tokens: ['address', 'appender', 'client', 'close', 'concurrent']...) from 4 documents (total 225 corpus positions)
# INFO:gensim.models.ldamodel:using symmetric eta at 0.2
# INFO:gensim.models.ldamodel:using serial LDA version on this node
# INFO:gensim.models.ldamulticore:running online LDA training, 5 topics, 10 passes over the supplied corpus of 4 documents, updating every 4000 documents, evaluating every ~4 documents, iterating 50x with a convergence threshold of 0.001000
# INFO:gensim.models.ldamulticore:training LDA model using 2 processes
# INFO:gensim.models.ldamulticore:PROGRESS: pass 0, dispatched chunk #0 = documents up to #4/4, outstanding queue size 1
# DEBUG:gensim.models.ldamodel:updating topics
# ...

# %%
p5_lda_code_res = []
p5_lda_test_res = []

for ce_data in p5_outliers['Code Extraction']:
    lm, coh_score = generate_lda(ce_data, 5)
    p5_lda_code_res.append((lm, coh_score))
    
for te_data in p5_outliers['Test Extraction']:
    lm, coh_score = generate_lda(te_data, 5)
    p5_lda_test_res.append((lm, coh_score))
# Out:
# INFO:gensim.corpora.dictionary:adding document #0 to Dictionary(0 unique tokens: [])
# INFO:gensim.corpora.dictionary:built Dictionary(122 unique tokens: ['builder', 'checker', 'database', 'dumper', 'entry']...) from 43 documents (total 1067 corpus positions)
# INFO:gensim.models.ldamodel:using symmetric eta at 0.2
# INFO:gensim.models.ldamodel:using serial LDA version on this node
# INFO:gensim.models.ldamulticore:running online LDA training, 5 topics, 10 passes over the supplied corpus of 43 documents, updating every 4000 documents, evaluating every ~43 documents, iterating 50x with a convergence threshold of 0.001000
# INFO:gensim.models.ldamulticore:training LDA model using 2 processes
# INFO:gensim.models.ldamulticore:PROGRESS: pass 0, dispatched chunk #0 = documents up to #43/43, outstanding queue size 1
# DEBUG:gensim.models.ldamodel:updating topics
# ...

# %%
# print coherence scores

for x in p1_lda_code_res:
    print(x)
# Out:
# (<gensim.models.ldamulticore.LdaMulticore object at 0x00000216ADA03488>, 0.3261670009777428)
# (<gensim.models.ldamulticore.LdaMulticore object at 0x00000216A3606108>, 0.43571567779316495)

# %%
for x in p1_lda_test_res:
    print(x)
# Out:
# (<gensim.models.ldamulticore.LdaMulticore object at 0x0000021690BD3508>, 0.34257105774922514)
# (<gensim.models.ldamulticore.LdaMulticore object at 0x0000021689968788>, 0.39365510444565127)

# %% [markdown]
# ### Outlier Modules LDA

# %%
p1_lda_code_kw = []
p1_lda_test_kw = []
p3_lda_code_kw = []
p3_lda_test_kw = []
p4_lda_code_kw = []
p4_lda_test_kw = []
p5_lda_code_kw = []
p5_lda_test_kw = []

# %%
import re

for lcr in p1_lda_code_res:
    
    lcr_lst = []
    
    for idx, topic in lcr[0].print_topics(-1):

        topic_cluster = re.sub(r'[^A-Za-z ]','',topic)

        lcr_lst.append(topic_cluster.split())
        
        topic_cluster = '-'.join(topic_cluster.split())

        print("\nTopic: {} \nWeights: {}\nCluster: {}\n".format(idx, topic, topic_cluster))
        print("=============================================================================")
        
    p1_lda_code_kw.append(lcr_lst)
# Out:
# INFO:gensim.models.ldamodel:topic #0 (0.010): 0.146*"logger" + 0.111*"extension" + 0.111*"loader" + 0.111*"lock" + 0.076*"key" + 0.076*"reentrant" + 0.076*"condition" + 0.076*"container" + 0.042*"hook" + 0.042*"shutdown"
# INFO:gensim.models.ldamodel:topic #1 (0.010): 0.042*"application" + 0.042*"config" + 0.042*"initializer" + 0.042*"logback" + 0.042*"max" + 0.042*"subdirectory" + 0.042*"spring" + 0.042*"path" + 0.042*"error" + 0.042*"context"
# INFO:gensim.models.ldamodel:topic #2 (0.010): 0.042*"application" + 0.042*"config" + 0.042*"initializer" + 0.042*"logback" + 0.042*"max" + 0.042*"subdirectory" + 0.042*"spring" + 0.042*"path" + 0.042*"error" + 0.042*"context"
# INFO:gensim.models.ldamodel:topic #3 (0.010): 0.193*"logger" + 0.193*"spring" + 0.101*"container" + 0.101*"context" + 0.101*"config" + 0.055*"path" + 0.055*"application" + 0.055*"xml" + 0.009*"hook" + 0.009*"key"
# ...

# %%
import re

for ltr in p1_lda_test_res:
    
    ltr_lst = []
    
    for idx, topic in ltr[0].print_topics(-1):

        topic_cluster = re.sub(r'[^A-Za-z ]','',topic)

        ltr_lst.append(topic_cluster.split())
        
        topic_cluster = '-'.join(topic_cluster.split())

        print("\nTopic: {} \nWeights: {}\nCluster: {}\n".format(idx, topic, topic_cluster))
        print("=============================================================================")
        
    p1_lda_test_kw.append(ltr_lst)
# Out:
# INFO:gensim.models.ldamodel:topic #0 (0.010): 0.250*"container" + 0.250*"logback" + 0.250*"logger" + 0.250*"spring"
# INFO:gensim.models.ldamodel:topic #1 (0.010): 0.250*"container" + 0.250*"logback" + 0.250*"logger" + 0.250*"spring"
# INFO:gensim.models.ldamodel:topic #2 (0.010): 0.250*"container" + 0.250*"logback" + 0.250*"logger" + 0.250*"spring"
# INFO:gensim.models.ldamodel:topic #3 (0.010): 0.724*"container" + 0.207*"spring" + 0.034*"logback" + 0.034*"logger"
# INFO:gensim.models.ldamodel:topic #4 (0.010): 0.429*"logger" + 0.327*"container" + 0.224*"logback" + 0.020*"spring"
# INFO:gensim.models.ldamodel:topic #0 (0.010): 0.030*"provider" + 0.030*"array" + 0.030*"url" + 0.030*"validation" + 0.030*"validator" + 0.030*"without" + 0.030*"invalid" + 0.030*"parameter" + 0.030*"arg" + 0.030*"map"
# ...

# %%
import re

for lcr in p3_lda_code_res:
    
    lcr_lst = []
    
    for idx, topic in lcr[0].print_topics(-1):

        topic_cluster = re.sub(r'[^A-Za-z ]','',topic)

        lcr_lst.append(topic_cluster.split())
        
        topic_cluster = '-'.join(topic_cluster.split())

        print("\nTopic: {} \nWeights: {}\nCluster: {}\n".format(idx, topic, topic_cluster))
        print("=============================================================================")
        
    p3_lda_code_kw.append(lcr_lst)
# Out:
# INFO:gensim.models.ldamodel:topic #0 (0.010): 0.042*"mode" + 0.042*"package" + 0.042*"result" + 0.042*"standalone" + 0.042*"entry" + 0.042*"port" + 0.042*"reactive" + 0.042*"program" + 0.042*"parse" + 0.042*"point"
# INFO:gensim.models.ldamodel:topic #1 (0.010): 0.042*"mode" + 0.042*"package" + 0.042*"result" + 0.042*"standalone" + 0.042*"entry" + 0.042*"port" + 0.042*"reactive" + 0.042*"program" + 0.042*"parse" + 0.042*"point"
# INFO:gensim.models.ldamodel:topic #2 (0.010): 0.042*"mode" + 0.042*"package" + 0.042*"result" + 0.042*"standalone" + 0.042*"entry" + 0.042*"port" + 0.042*"reactive" + 0.042*"program" + 0.042*"parse" + 0.042*"point"
# INFO:gensim.models.ldamodel:topic #3 (0.010): 0.119*"application" + 0.119*"cluster" + 0.119*"point" + 0.119*"entry" + 0.082*"standalone" + 0.082*"program" + 0.082*"package" + 0.045*"reactive" + 0.045*"mode" + 0.045*"support"
# ...

# %%
import re

for ltr in p3_lda_test_res:
    
    ltr_lst = []
    
    for idx, topic in ltr[0].print_topics(-1):

        topic_cluster = re.sub(r'[^A-Za-z ]','',topic)

        ltr_lst.append(topic_cluster.split())
        
        topic_cluster = '-'.join(topic_cluster.split())

        print("\nTopic: {} \nWeights: {}\nCluster: {}\n".format(idx, topic, topic_cluster))
        print("=============================================================================")
        
    p3_lda_test_kw.append(ltr_lst)
# Out:
# INFO:gensim.models.ldamodel:topic #0 (0.010): 0.034*"parse" + 0.034*"path" + 0.034*"logger" + 0.034*"manually" + 0.034*"miss" + 0.034*"option" + 0.034*"job" + 0.034*"parser" + 0.034*"setting" + 0.034*"restore"
# INFO:gensim.models.ldamodel:topic #1 (0.010): 0.034*"parse" + 0.034*"path" + 0.034*"logger" + 0.034*"manually" + 0.034*"miss" + 0.034*"option" + 0.034*"job" + 0.034*"parser" + 0.034*"setting" + 0.034*"restore"
# INFO:gensim.models.ldamodel:topic #2 (0.010): 0.034*"parse" + 0.034*"path" + 0.034*"logger" + 0.034*"manually" + 0.034*"miss" + 0.034*"option" + 0.034*"job" + 0.034*"parser" + 0.034*"setting" + 0.034*"restore"
# INFO:gensim.models.ldamodel:topic #3 (0.010): 0.165*"parse" + 0.106*"configuration" + 0.077*"cluster" + 0.047*"entrypoint" + 0.047*"job" + 0.032*"savepoint" + 0.032*"argument" + 0.032*"option" + 0.032*"conf" + 0.032*"application"
# ...

# %%
import re

for lcr in p4_lda_code_res:
    
    lcr_lst = []
    
    for idx, topic in lcr[0].print_topics(-1):

        topic_cluster = re.sub(r'[^A-Za-z ]','',topic)

        lcr_lst.append(topic_cluster.split())
        
        topic_cluster = '-'.join(topic_cluster.split())

        print("\nTopic: {} \nWeights: {}\nCluster: {}\n".format(idx, topic, topic_cluster))
        print("=============================================================================")
        
    p4_lda_code_kw.append(lcr_lst)
# Out:
# INFO:gensim.models.ldamodel:topic #0 (0.010): 0.160*"producer" + 0.129*"appender" + 0.078*"instance" + 0.069*"group" + 0.057*"address" + 0.057*"server" + 0.046*"location" + 0.046*"info" + 0.035*"map" + 0.035*"close"
# INFO:gensim.models.ldamodel:topic #1 (0.010): 0.111*"layout" + 0.095*"event" + 0.094*"topic" + 0.093*"tag" + 0.092*"producer" + 0.057*"server" + 0.057*"address" + 0.056*"log" + 0.055*"group" + 0.034*"appender"
# INFO:gensim.models.ldamodel:topic #2 (0.010): 0.023*"exception" + 0.023*"filter" + 0.023*"log" + 0.023*"option" + 0.023*"require" + 0.023*"skeleton" + 0.023*"tag" + 0.023*"topic" + 0.023*"build" + 0.023*"builder"
# INFO:gensim.models.ldamodel:topic #3 (0.010): 0.154*"builder" + 0.084*"filter" + 0.084*"layout" + 0.072*"producer" + 0.061*"appender" + 0.049*"address" + 0.049*"server" + 0.049*"group" + 0.049*"tag" + 0.049*"topic"
# ...

# %%
import re

for ltr in p4_lda_test_res:
    
    ltr_lst = []
    
    for idx, topic in ltr[0].print_topics(-1):

        topic_cluster = re.sub(r'[^A-Za-z ]','',topic)

        ltr_lst.append(topic_cluster.split())
        
        topic_cluster = '-'.join(topic_cluster.split())

        print("\nTopic: {} \nWeights: {}\nCluster: {}\n".format(idx, topic, topic_cluster))
        print("=============================================================================")
        
    p4_lda_test_kw.append(ltr_lst)
# Out:
# INFO:gensim.models.ldamodel:topic #0 (0.010): 0.042*"interrupt" + 0.042*"property" + 0.042*"write" + 0.042*"client" + 0.042*"init" + 0.042*"throwable" + 0.042*"joran" + 0.042*"xml" + 0.042*"message" + 0.042*"type"
# INFO:gensim.models.ldamodel:topic #1 (0.010): 0.154*"init" + 0.154*"xml" + 0.154*"type" + 0.026*"property" + 0.026*"write" + 0.026*"client" + 0.026*"throwable" + 0.026*"message" + 0.026*"interrupt" + 0.026*"joran"
# INFO:gensim.models.ldamodel:topic #2 (0.010): 0.232*"init" + 0.160*"logback" + 0.160*"type" + 0.087*"joran" + 0.084*"property" + 0.015*"write" + 0.015*"client" + 0.015*"throwable" + 0.015*"xml" + 0.015*"interrupt"
# INFO:gensim.models.ldamodel:topic #3 (0.010): 0.042*"interrupt" + 0.042*"property" + 0.042*"write" + 0.042*"client" + 0.042*"init" + 0.042*"throwable" + 0.042*"joran" + 0.042*"xml" + 0.042*"message" + 0.042*"type"
# ...

# %%
import re

for lcr in p5_lda_code_res:
    
    lcr_lst = []
    
    for idx, topic in lcr[0].print_topics(-1):

        topic_cluster = re.sub(r'[^A-Za-z ]','',topic)

        lcr_lst.append(topic_cluster.split())
        
        topic_cluster = '-'.join(topic_cluster.split())

        print("\nTopic: {} \nWeights: {}\nCluster: {}\n".format(idx, topic, topic_cluster))
        print("=============================================================================")
        
    p5_lda_code_kw.append(lcr_lst)
# Out:
# INFO:gensim.models.ldamodel:topic #0 (0.010): 0.142*"scale" + 0.090*"node" + 0.090*"ast" + 0.083*"ctx" + 0.083*"context" + 0.077*"visit" + 0.042*"show" + 0.036*"algorithm" + 0.022*"definition" + 0.022*"visitor"
# INFO:gensim.models.ldamodel:topic #1 (0.010): 0.129*"sql" + 0.087*"table" + 0.048*"dumper" + 0.034*"builder" + 0.032*"postgre" + 0.029*"scale" + 0.028*"actual" + 0.028*"gauss" + 0.028*"open" + 0.024*"inventory"
# INFO:gensim.models.ldamodel:topic #2 (0.010): 0.009*"statement" + 0.009*"scale" + 0.009*"open" + 0.009*"gauss" + 0.009*"sql" + 0.008*"dumper" + 0.008*"updatable" + 0.008*"job" + 0.008*"ral" + 0.008*"checker"
# INFO:gensim.models.ldamodel:topic #3 (0.010): 0.140*"statement" + 0.105*"scale" + 0.070*"sql" + 0.045*"ral" + 0.034*"updater" + 0.034*"collection" + 0.034*"type" + 0.031*"job" + 0.023*"object" + 0.023*"result"
# ...

# %%
import re

for ltr in p5_lda_test_res:
    
    ltr_lst = []
    
    for idx, topic in ltr[0].print_topics(-1):

        topic_cluster = re.sub(r'[^A-Za-z ]','',topic)

        ltr_lst.append(topic_cluster.split())
        
        topic_cluster = '-'.join(topic_cluster.split())

        print("\nTopic: {} \nWeights: {}\nCluster: {}\n".format(idx, topic, topic_cluster))
        print("=============================================================================")
        
    p5_lda_test_kw.append(ltr_lst)
# Out:
# INFO:gensim.models.ldamodel:topic #0 (0.010): 0.177*"sql" + 0.073*"entry" + 0.073*"scale" + 0.072*"builder" + 0.049*"build" + 0.049*"pipeline" + 0.048*"record" + 0.038*"instantiation" + 0.038*"type" + 0.038*"database"
# INFO:gensim.models.ldamodel:topic #1 (0.010): 0.221*"source" + 0.098*"configuration" + 0.071*"target" + 0.060*"sql" + 0.057*"jdbc" + 0.057*"wrapper" + 0.044*"config" + 0.044*"prepare" + 0.030*"table" + 0.030*"sharding"
# INFO:gensim.models.ldamodel:topic #2 (0.010): 0.139*"importer" + 0.095*"record" + 0.094*"manager" + 0.094*"sql" + 0.094*"source" + 0.050*"mock" + 0.049*"create" + 0.049*"builder" + 0.049*"config" + 0.049*"configuration"
# INFO:gensim.models.ldamodel:topic #3 (0.010): 0.017*"manager" + 0.017*"importer" + 0.017*"column" + 0.017*"build" + 0.017*"record" + 0.017*"mock" + 0.017*"insert" + 0.017*"target" + 0.017*"builder" + 0.017*"sum"
# ...

# %%
p1_lda_code_df = pd.DataFrame(p1_lda_code_kw, columns=['Topic1', 'Topic2', 'Topic3', 'Topic4', 'Topic5'])
p1_lda_code_df
# Out:
#                                               Topic1  \
# 0  [logger, extension, loader, lock, key, reentra...
# 1  [map, time, expiration, expire, interval, live...
#
#                                               Topic2  \
# 0  [application, config, initializer, logback, ma...
# 1  [method, validator, validation, url, parameter...
#
#                                               Topic3  \
# 0  [application, config, initializer, logback, ma...
# 1  [object, key, expire, time, map, live, thread,...
#
#                                               Topic4  \
# 0  [logger, spring, container, context, config, p...
# 1  [cache, url, factory, create, object, invocati...
#
#                                               Topic5
# 0  [container, level, logback, max, history, erro...
# 1  [map, expire, method, time, thread, expiration...

# %%
p1_lda_test_df = pd.DataFrame(p1_lda_test_kw, columns=['Topic1', 'Topic2', 'Topic3', 'Topic4', 'Topic5'])
p1_lda_test_df
# Out:
#                                               Topic1  \
# 0               [container, logback, logger, spring]
# 1  [provider, array, url, validation, validator, ...
#
#                                               Topic2  \
# 0               [container, logback, logger, spring]
# 1  [cache, factory, expire, local, lru, thread, c...
#
#                                               Topic3  \
# 0               [container, logback, logger, spring]
# 1  [provider, array, url, validation, validator, ...
#
#                                               Topic4  \
# 0               [container, spring, logback, logger]
# 1  [invoker, mock, type, cache, method, filter, a...
#
#                                               Topic5
# 0               [logger, container, logback, spring]
# 1  [validation, parameter, mock, validator, rpc, ...

# %%
p3_lda_code_df = pd.DataFrame(p3_lda_code_kw, columns=['Topic1', 'Topic2', 'Topic3', 'Topic4', 'Topic5'])
p3_lda_code_df
# Out:
#                                               Topic1  \
# 0  [mode, package, result, standalone, entry, por...
# 1  [user, event, edit, irc, wikipedia, diff, chan...
# 2  [collection, key, create, factory, code, confi...
# 3  [field, accessor, product, record, serializer,...
#
#                                               Topic2  \
# 0  [mode, package, result, standalone, entry, por...
# 1  [user, irc, edit, msg, wikipedia, chan, nick, ...
# 2  [driver, resource, external, factory, configur...
# 3  [scala, record, value, uid, tuple, simple, ser...
#
#                                               Topic3  \
# 0  [mode, package, result, standalone, entry, por...
# 1  [wikipedia, source, edit, channel, host, port,...
# 2  [key, property, info, gpu, hash, resource, cod...
# 3  [scala, record, value, uid, tuple, simple, ser...
#
#                                               Topic4  \
# 0  [application, cluster, point, entry, standalon...
# ...

# %%
p3_lda_test_df = pd.DataFrame(p3_lda_test_kw, columns=['Topic1', 'Topic2', 'Topic3', 'Topic4', 'Topic5'])
p3_lda_test_df
# Out:
#                                               Topic1  \
# 0  [parse, path, logger, manually, miss, option, ...
# 1  [temporarily, time, nanos, object, queue, sour...
# 2  [config, driver, script, zero, amount, preempt...
# 3  [factory, field, stateful, text, accessor, fun...
#
#                                               Topic2  \
# 0  [parse, path, logger, manually, miss, option, ...
# 1  [temporarily, time, nanos, object, queue, sour...
# 2  [driver, gpu, script, path, inexecutable, ille...
# 3  [field, scala, factory, product, logger, load,...
#
#                                               Topic3  \
# 0  [parse, path, logger, manually, miss, option, ...
# 1  [source, collect, mark, logger, context, edit,...
# 2  [config, driver, script, zero, amount, preempt...
# 3  [path, write, mode, millis, fail, delimiter, c...
#
#                                               Topic4  \
# 0  [parse, configuration, cluster, entrypoint, jo...
# ...

# %%
p4_lda_code_df = pd.DataFrame(p4_lda_code_kw, columns=['Topic1', 'Topic2', 'Topic3', 'Topic4', 'Topic5'])
p4_lda_code_df
# Out:
#                                               Topic1  \
# 0  [producer, appender, instance, group, address,...
# 1  [option, command, line, app, properties, build...
#
#                                               Topic2  \
# 0  [layout, event, topic, tag, producer, server, ...
# 1  [watch, logger, service, listener, file, hash,...
#
#                                               Topic3  \
# 0  [exception, filter, log, option, require, skel...
# 1  [property, server, help, line, option, options...
#
#                                               Topic4  \
# 0  [builder, filter, layout, producer, appender, ...
# 1  [shutdown, thread, logger, internal, log, hook...
#
#                                               Topic5
# 0  [layout, event, producer, tag, server, log, ad...
# 1  [property, server, help, line, option, options...

# %%
p4_lda_test_df = pd.DataFrame(p4_lda_test_kw, columns=['Topic1', 'Topic2', 'Topic3', 'Topic4', 'Topic5'])
p4_lda_test_df
# Out:
#                                               Topic1  \
# 0  [interrupt, property, write, client, init, thr...
# 1  [service, one, two, temporary, temp, single, c...
#
#                                               Topic2  \
# 0  [init, xml, type, property, write, client, thr...
# 1  [service, one, two, temporary, temp, single, c...
#
#                                               Topic3  \
# 0  [init, logback, type, joran, property, write, ...
# 1  [path, watch, change, two, folder, modify, del...
#
#                                               Topic4  \
# 0  [interrupt, property, write, client, init, thr...
# 1  [watch, path, change, folder, two, file, tempo...
#
#                                               Topic5
# 0  [message, mock, list, write, invocation, copy,...
# 1  [watch, path, change, two, folder, single, del...

# %%
p5_lda_code_df = pd.DataFrame(p5_lda_code_kw, columns=['Topic1', 'Topic2', 'Topic3', 'Topic4', 'Topic5'])
p5_lda_code_df
# Out:
#                                               Topic1  \
# 0  [scale, node, ast, ctx, context, visit, show, ...
# 1  [spi, order, register, services, collection, c...
# 2  [statement, open, gauss, select, optional, cre...
#
#                                               Topic2  \
# 0  [sql, table, dumper, builder, postgre, scale, ...
# 1  [cache, services, map, collection, type, key, ...
# 2  [statement, sql, drop, alter, create, server, ...
#
#                                               Topic3  \
# 0  [statement, scale, open, gauss, sql, dumper, u...
# 1  [optional, spi, register, registry, service, f...
# 2  [context, ctx, visit, node, ast, clause, table...
#
#                                               Topic4  \
# 0  [statement, scale, sql, ral, updater, collecti...
# 1  [service, clazz, find, provider, loader, insta...
# 2  [visitor, sql, show, statement, type, parser, ...
#
#                                               Topic5
# ...

# %%
p5_lda_test_df = pd.DataFrame(p5_lda_test_kw, columns=['Topic1', 'Topic2', 'Topic3', 'Topic4', 'Topic5'])
p5_lda_test_df
# Out:
#                                               Topic1  \
# 0  [sql, entry, scale, builder, build, pipeline, ...
# 1  [instance, service, exist, singleton, loader, ...
# 2  [safe, list, statement, link, segment, integer...
#
#                                               Topic2  \
# 0  [source, configuration, target, sql, jdbc, wra...
# 1  [service, register, registered, spi, exist, ty...
# 2  [segment, sql, statement, limit, table, withou...
#
#                                               Topic3  \
# 0  [importer, record, manager, sql, source, mock,...
# 1  [order, service, register, cache, find, spi, r...
# 2  [extract, paren, predicate, leave, match, cond...
#
#                                               Topic4  \
# 0  [manager, importer, column, build, record, moc...
# 1  [registry, clean, type, require, prop, propert...
# 2  [statement, sql, select, update, parse, trunca...
#
#                                               Topic5
# ...

# %%
p1_lda_code_lst = p1_lda_code_df.apply(lambda x: [item for sublist in x for item in sublist], axis=1)
p1_lda_test_lst = p1_lda_test_df.apply(lambda x: [item for sublist in x for item in sublist], axis=1)

# %%
p1_lda_res_df = pd.DataFrame(list(zip(p1_lda_code_lst, p1_lda_test_lst)), columns=['Code', 'Test'])
p1_lda_res_df.insert(loc=0, column='P1 Module', value=p1_outliers['P1 Module'].tolist())

# %%
p3_lda_code_lst = p3_lda_code_df.apply(lambda x: [item for sublist in x for item in sublist], axis=1)
p3_lda_test_lst = p3_lda_test_df.apply(lambda x: [item for sublist in x for item in sublist], axis=1)

# %%
p3_lda_res_df = pd.DataFrame(list(zip(p3_lda_code_lst, p3_lda_test_lst)), columns=['Code', 'Test'])
p3_lda_res_df.insert(loc=0, column='P3 Module', value=p3_outliers['P3 Module'].tolist())

# %%
p4_lda_code_lst = p4_lda_code_df.apply(lambda x: [item for sublist in x for item in sublist], axis=1)
p4_lda_test_lst = p4_lda_test_df.apply(lambda x: [item for sublist in x for item in sublist], axis=1)

# %%
p4_lda_res_df = pd.DataFrame(list(zip(p4_lda_code_lst, p4_lda_test_lst)), columns=['Code', 'Test'])
p4_lda_res_df.insert(loc=0, column='P4 Module', value=p4_outliers['P4 Module'].tolist())

# %%
p5_lda_code_lst = p5_lda_code_df.apply(lambda x: [item for sublist in x for item in sublist], axis=1)
p5_lda_test_lst = p5_lda_test_df.apply(lambda x: [item for sublist in x for item in sublist], axis=1)

# %%
p5_lda_res_df = pd.DataFrame(list(zip(p5_lda_code_lst, p5_lda_test_lst)), columns=['Code', 'Test'])
p5_lda_res_df.insert(loc=0, column='P5 Module', value=p5_outliers['P5 Module'].tolist())

# %%
p1_lda_res_df
# Out:
#          P1 Module                                               Code  \
# 0  dubbo-container  [logger, extension, loader, lock, key, reentra...
# 1     dubbo-filter  [map, time, expiration, expire, interval, live...
#
#                                                 Test
# 0  [container, logback, logger, spring, container...
# 1  [provider, array, url, validation, validator, ...

# %%
p3_lda_res_df
# Out:
#                   P3 Module  \
# 0           flink-container
# 1             flink-contrib
# 2  flink-external-resources
# 3     flink-streaming-scala
#
#                                                 Code  \
# 0  [mode, package, result, standalone, entry, por...
# 1  [user, event, edit, irc, wikipedia, diff, chan...
# 2  [collection, key, create, factory, code, confi...
# 3  [field, accessor, product, record, serializer,...
#
#                                                 Test
# 0  [parse, path, logger, manually, miss, option, ...
# 1  [temporarily, time, nanos, object, queue, sour...
# 2  [config, driver, script, zero, amount, preempt...
# 3  [factory, field, stateful, text, accessor, fun...

# %%
p4_lda_res_df
# Out:
#      P4 Module                                               Code  \
# 0  logappender  [producer, appender, instance, group, address,...
# 1      srvutil  [option, command, line, app, properties, build...
#
#                                                 Test
# 0  [interrupt, property, write, client, init, thr...
# 1  [service, one, two, temporary, temp, single, c...

# %%
p5_lda_res_df
# Out:
#                    P5 Module  \
# 0     shardingsphere-scaling
# 1         shardingsphere-spi
# 2  shardingsphere-sql-parser
#
#                                                 Code  \
# 0  [scale, node, ast, ctx, context, visit, show, ...
# 1  [spi, order, register, services, collection, c...
# 2  [statement, open, gauss, select, optional, cre...
#
#                                                 Test
# 0  [sql, entry, scale, builder, build, pipeline, ...
# 1  [instance, service, exist, singleton, loader, ...
# 2  [safe, list, statement, link, segment, integer...

# %%
def show_topic_outliers(a, b): 
    a = set(a)
    b = set(b)
    c = a.symmetric_difference(b) # set of concepts that do not belong to intersection, not bidirectional
    
    return list(c)

# %%
p1_lda_res_df['Topic Outliers'] = p1_lda_res_df.apply(lambda x: show_topic_outliers(x.Code, x.Test), axis=1)
p3_lda_res_df['Topic Outliers'] = p3_lda_res_df.apply(lambda x: show_topic_outliers(x.Code, x.Test), axis=1)
p4_lda_res_df['Topic Outliers'] = p4_lda_res_df.apply(lambda x: show_topic_outliers(x.Code, x.Test), axis=1)
p5_lda_res_df['Topic Outliers'] = p5_lda_res_df.apply(lambda x: show_topic_outliers(x.Code, x.Test), axis=1)

# %%
p1_lda_res_df
# Out:
#          P1 Module                                               Code  \
# 0  dubbo-container  [logger, extension, loader, lock, key, reentra...
# 1     dubbo-filter  [map, time, expiration, expire, interval, live...
#
#                                                 Test  \
# 0  [container, logback, logger, spring, container...
# 1  [provider, array, url, validation, validator, ...
#
#                                       Topic Outliers
# 0  [key, initializer, reentrant, history, xml, co...
# 1  [create, lru, rpc, constraint, value, expirati...

# %%
p3_lda_res_df
# Out:
#                   P3 Module  \
# 0           flink-container
# 1             flink-contrib
# 2  flink-external-resources
# 3     flink-streaming-scala
#
#                                                 Code  \
# 0  [mode, package, result, standalone, entry, por...
# 1  [user, event, edit, irc, wikipedia, diff, chan...
# 2  [collection, key, create, factory, code, confi...
# 3  [field, accessor, product, record, serializer,...
#
#                                                 Test  \
# 0  [parse, path, logger, manually, miss, option, ...
# 1  [temporarily, time, nanos, object, queue, sour...
# 2  [config, driver, script, zero, amount, preempt...
# 3  [factory, field, stateful, text, accessor, fun...
#
#                                       Topic Outliers
# 0  [create, argument, line, miss, command, point,...
# 1  [log, event, watermark, collect, diff, queue, ...
# 2  [create, external, key, code, discovery, retri...
# 3  [stateful, millis, text, uid, close, simple, s...

# %%
p4_lda_res_df
# Out:
#      P4 Module                                               Code  \
# 0  logappender  [producer, appender, instance, group, address,...
# 1      srvutil  [option, command, line, app, properties, build...
#
#                                                 Test  \
# 0  [interrupt, property, write, client, init, thr...
# 1  [service, one, two, temporary, temp, single, c...
#
#                                       Topic Outliers
# 0  [log, type, event, copy, info, init, write, pr...
# 1  [app, callable, message, help, log, build, mod...

# %%
p5_lda_res_df
# Out:
#                    P5 Module  \
# 0     shardingsphere-scaling
# 1         shardingsphere-spi
# 2  shardingsphere-sql-parser
#
#                                                 Code  \
# 0  [scale, node, ast, ctx, context, visit, show, ...
# 1  [spi, order, register, services, collection, c...
# 2  [statement, open, gauss, select, optional, cre...
#
#                                                 Test  \
# 0  [sql, entry, scale, builder, build, pipeline, ...
# 1  [instance, service, exist, singleton, loader, ...
# 2  [safe, list, statement, link, segment, integer...
#
#                                       Topic Outliers
# 0  [insert, privilege, target, updatable, build, ...
# 1  [access, uid, runtime, value, instantiation, f...
# 2  [brace, big, insert, tree, simple, match, para...

# %%
p1_lda_res_df.to_csv("output/p1_outliers_df.csv", index=False)
p3_lda_res_df.to_csv("output/p3_outliers_df.csv", index=False)
p4_lda_res_df.to_csv("output/p4_outliers_df.csv", index=False)
p5_lda_res_df.to_csv("output/p5_outliers_df.csv", index=False)

# %% [markdown]
# #### Using logappender as an example:

# %%
outlier_df = p4_lda_res_df[p4_lda_res_df['P4 Module']=='logappender']

# %%
outlier_df
# Out:
#      P4 Module                                               Code  \
# 0  logappender  [producer, appender, instance, group, address,...
#
#                                                 Test  \
# 0  [interrupt, property, write, client, init, thr...
#
#                                       Topic Outliers
# 0  [log, type, event, copy, info, init, write, pr...
